# %% [markdown]
# # Baseline

# %% [markdown]
# ## Read data

# %%
#Membaca file
def read_file_train_init_table(fname):
    words = []
    tags = []
    with open(fname) as f:
        content = f.readlines()
    content = [x.strip() for x in content]
    idx_line = 0
    
    while idx_line < len(content):
        word = []
        tag = []
        while not content[idx_line].startswith('</kalimat'):
            if not content[idx_line].startswith('<kalimat'):
                content_part = content[idx_line].split('\t')
                word.append(content_part[0].lower())
                tag.append(content_part[1])
            idx_line = idx_line + 1
        words.append(word)
        tags.append(tag)
        idx_line = idx_line + 2
    return words, tags
words,tags = read_file_train_init_table('Data Latih.txt')

#Membagi data latih menjadi 2 yaitu 1000 data train dan 20 data testing
training_sentences = words[:1000]
training_tags = tags[:1000]
test_sentences = words[1000:1020]
test_tags = tags[1000:1020]

# %%
#Menghitung frekuensi tag untuk setiap kata
def word_tag(words, tags):
    word_tags = {}
    for word,tag in zip(words,tags):
        for wr,tg in zip(word,tag):
            if wr in word_tags:
                if tg in word_tags[wr]:
                    word_tags[wr][tg] += 1
                else:
                    word_tags[wr][tg] = 1
            else:
                word_tags[wr] = {}
                word_tags[wr][tg] = 1
    return word_tags
word_tag = word_tag(training_sentences,training_tags)
print("Word Tag : ")
print("-----------")
word_tag
# Out:
# Word Tag :
# -----------
# {'kera': {'NN': 1},
#  'untuk': {'SC': 124, 'IN': 105},
#  'amankan': {'VB': 1},
#  'pesta olahraga': {'NN': 1, 'NNP': 1},
#  'pemerintah': {'NNP': 8, 'NN': 70},
#  'kota': {'NNP': 3},
#  'delhi': {'NNP': 5},
#  'mengerahkan': {'VB': 1},
#  'monyet': {'NN': 15},
#  'mengusir': {'VB': 4},
#  'monyet-monyet': {'NN': 2},
#  'lain': {'JJ': 29},
#  'yang': {'SC': 513, 'DT': 4},
#  'berbadan': {'VB': 2},
#  'lebih': {'RB': 82},
#  'kecil': {'JJ': 15},
#  'dari': {'IN': 244},
#  'arena': {'NN': 2},
#  'persemakmuran': {'NNP': 1},
#  '.': {'Z': 981, 'NNP': 13},
#  'beberapa': {'CD': 21},
#  'laporan': {'NN': 17},
#  'menyebutkan': {'VB': 10},
#  'setidaknya': {'RB': 2},
#  '10': {'CD': 21},
#  'ditempatkan': {'VB': 2},
#  'di': {'IN': 358},
#  'luar': {'NN': 5, 'NNP': 1},
#  'lomba': {'NN': 1},
#  'dan': {'CC': 462, 'NNP': 5},
#  'pertandingan': {'NN': 1},
#  'ibukota': {'NNP': 2},
#  'india': {'NNP': 6},
#  'pemkot': {'NNP': 2, 'NN': 2},
#  'memiliki': {'VB': 19},
#  '28': {'CD': 5},
#  'berencana': {'VB': 8},
#  'mendatangkan': {'VB': 2},
#  'sejenis': {'NN': 1},
#  'negara bagian': {'NNP': 1, 'NN': 1},
#  'rajasthan': {'NNP': 1},
#  'jumlah': {'NN': 20},
#  'mencapai': {'VB': 94},
#  'ribuan': {'CD': 1},
#  ',': {'Z': 1372},
#  'sebagian besar': {'NN': 2},
#  'berada': {'VB': 14},
#  'kantor-kantor': {'NN': 1},
#  'hewan': {'NN': 1},
#  'ini': {'PR': 204},
#  'dianggap': {'VB': 4},
#  'mengganggu': {'VB': 3},
#  'ketertiban': {'NN': 1},
#  'umum': {'JJ': 13, 'NN': 1, 'NNP': 1},
#  'jenis': {'NN': 5},
#  'dikerahkan': {'VB': 3},
#  'besar': {'JJ': 34, 'NNP': 1},
#  'berekor': {'VB': 1},
#  'panjang': {'JJ': 4},
#  'wajah': {'NN': 2},
#  'berwarna': {'VB': 1},
#  'hitam': {'JJ': 1},
#  'diikat': {'VB': 1},
#  'dengan': {'IN': 193, 'SC': 52, 'X': 1},
#  'tali': {'NN': 2},
#  'pelatih': {'NN': 1},
#  'mengawasi': {'VB': 2},
#  'mereka': {'PRP': 29},
#  'akan': {'MD': 190, 'IN': 1},
#  'melepas': {'VB': 4},
#  'begitu': {'SC': 1, 'RB': 1, 'PR': 2},
#  'mendekat': {'VB': 1},
#  'kantor': {'NNP': 6, 'NN': 2},
#  'berita': {'NNP': 1},
#  'afp': {'NNP': 4},
#  'melaporkan': {'VB': 4},
#  'stadion': {'NN': 3},
#  'tinju': {'NN': 1},
#  'hockey': {'FW': 1},
#  'mendapatkan': {'VB': 3},
#  'perhatian': {'NN': 2},
#  'khusus': {'JJ': 15},
#  'karena': {'SC': 43, 'IN': 31},
#  'sering': {'RB': 3},
#  'diserbu': {'VB': 1},
#  'dua': {'CD': 24},
#  'serbuan': {'NN': 2},
#  '"': {'Z': 70},
#  'tersebut': {'PR': 111},
#  'kata': {'VB': 161, 'NN': 1},
#  'devender': {'NNP': 1},
#  'prasad': {'NNP': 1},
#  'pejabat': {'NN': 4, 'NNP': 1},
#  'kepada': {'IN': 56},
#  'kantor berita': {'NNP': 3},
#  'selama': {'IN': 23, 'SC': 2},
#  'bertahun-tahun': {'CD': 1},
#  'warga': {'NN': 2},
#  'binatang': {'NN': 2},
#  'menaiki': {'VB': 1},
#  'kereta': {'NN': 1},
#  'metro': {'NN': 1},
#  'bahkan': {'RB': 10},
#  'berkeliaran': {'VB': 1},
#  'kompleks': {'NN': 1},
#  'gedung': {'NN': 1, 'NNP': 10},
#  'parlemen': {'NN': 11, 'NNP': 2},
#  'belum': {'NEG': 27},
#  'lama': {'JJ': 2},
#  'kawanan': {'NN': 3},
#  'menyerbu': {'VB': 1},
#  'perdana menteri': {'NN': 3},
#  'departemen': {'NN': 3, 'NNP': 5},
#  'pertahanan': {'NN': 1},
#  'tidak': {'NEG': 79},
#  'bisa': {'MD': 39},
#  'dibunuh': {'VB': 1},
#  'masyarakat': {'NN': 13},
#  'menganggap': {'VB': 2},
#  'suci': {'JJ': 1},
#  'selain': {'CC': 1, 'IN': 11},
#  'harus': {'MD': 15},
#  'juga': {'RB': 73},
#  'kesulitan': {'VB': 3, 'NN': 2},
#  'mengatasi': {'VB': 5},
#  'wabah': {'NN': 1},
#  'demam berdarah': {'NN': 1},
#  'curah': {'NN': 1},
#  'hujan': {'NN': 1},
#  'tinggi': {'JJ': 33, 'NN': 5},
#  'menyebabkan': {'VB': 5},
#  'banyak': {'CD': 25},
#  'genangan': {'NN': 2},
#  'tempat': {'NN': 5},
#  'ideal': {'JJ': 2},
#  'bagi': {'IN': 23},
#  'nyamuk': {'NN': 2},
#  'aedes': {'NNP': 1},
#  'berkembang biak': {'VB': 1},
#  'telah': {'MD': 66},
#  'menempatkan': {'VB': 2},
#  'ikan': {'NN': 1},
#  'berbagai': {'CD': 11},
#  'air': {'NN': 5, 'NNP': 1},
#  'memangsa': {'VB': 1},
#  'telur': {'NN': 1},
#  'miliarder': {'NN': 3},
#  'as': {'NNP': 151},
#  'jamu': {'VB': 1},
#  'orang kaya': {'NN': 1},
#  'cina': {'NNP': 6},
#  'amerika': {'NNP': 12},
#  'bill': {'NNP': 1},
#  'gates': {'NNP': 2},
#  'warren': {'NNP': 1},
#  'buffett': {'NNP': 2},
#  'mengadakan': {'VB': 3},
#  'jamuan': {'NN': 3},
#  'makan malam': {'NN': 3},
#  'beijing': {'NNP': 1},
#  'sejumlah': {'CD': 7, 'NN': 3},
#  'orang': {'NN': 16, 'NND': 2},
#  'terkaya': {'JJ': 3},
#  'mengatakan': {'VB': 91},
#  'mempelajari': {'VB': 1},
#  'kegiatan': {'NN': 6},
#  'amal': {'NN': 5},
#  'negara': {'NN': 56, 'NNP': 9},
#  'itu': {'PR': 147},
#  'menduga': {'VB': 1},
#  'ingin': {'RB': 7},
#  'membujuk': {'VB': 2},
#  'para': {'DT': 12},
#  'tamu': {'NN': 2},
#  'agar': {'SC': 9},
#  'menyumbang': {'VB': 4},
#  'kedua': {'CD': 9, 'OD': 7},
#  'dunia': {'NN': 21, 'NNP': 17},
#  'sudah': {'MD': 32},
#  'berhasil': {'VB': 10},
#  'sangat': {'RB': 25},
#  'kaya': {'JJ': 2},
#  'menyumbangkan': {'VB': 3},
#  'separuh': {'CD': 1},
#  'kekayaan': {'NN': 3},
#  'ada': {'VB': 29},
#  'kerahasiaan': {'NN': 1},
#  'mengenai': {'IN': 11, 'SC': 1},
#  'acara': {'NN': 7},
#  'pihak': {'NN': 25},
#  'penyelenggara': {'NN': 1},
#  'membeberkan': {'VB': 1},
#  'nama-nama': {'NN': 2},
#  'salah satu': {'CD': 11},
#  'menghadiri': {'VB': 2},
#  'adalah': {'VB': 36},
#  'chen': {'NNP': 1},
#  'guangbiao': {'NNP': 1},
#  'seorang': {'NND': 10},
#  'meraup': {'VB': 1},
#  'bisnis': {'NN': 14},
#  'mendaur ulang': {'VB': 1},
#  'sampah': {'NN': 1},
#  'industri': {'NN': 30, 'NNP': 1},
#  'bangunan': {'NN': 1},
#  'dia': {'PRP': 77},
#  'bbc': {'NNP': 1},
#  'bahwa': {'SC': 37},
#  'seluruh': {'CD': 16},
#  'harta': {'NN': 1},
#  '-nya': {'PRP': 442},
#  'bila': {'SC': 4},
#  'meninggal': {'VB': 2},
#  'beramal': {'VB': 2},
#  'membantu': {'VB': 10},
#  'menjadi': {'VB': 122},
#  'bagian': {'NN': 8},
#  'budaya': {'NN': 2},
#  '5.000': {'CD': 1},
#  'tahun': {'NN': 171, 'NNP': 3},
#  'tetapi': {'CC': 11},
#  'resmi': {'JJ': 7},
#  'baru': {'MD': 12, 'JJ': 15, 'NNP': 2},
#  'dikembangkan': {'VB': 2},
#  'dalam': {'IN': 183, 'NN': 6, 'SC': 6, 'X': 1},
#  '30': {'CD': 20},
#  'terakhir': {'JJ': 11, 'OD': 1},
#  'sejak': {'SC': 3, 'IN': 21},
#  'kami': {'PRP': 20},
#  'menerapkan': {'VB': 1},
#  'reformasi ekonomi': {'NN': 1},
#  'mulai': {'MD': 15, 'VB': 6},
#  'baru-baru ini': {'RB': 3},
#  'saja': {'RB': 11},
#  'memberi': {'VB': 4},
#  'makan': {'NN': 1, 'VB': 2},
#  'diri': {'NN': 3},
#  'sendiri': {'NN': 9, 'JJ': 1, 'PRP': 5},
#  'uang': {'NN': 3},
#  'berkembang': {'VB': 4},
#  'sebaik': {'JJ': 2},
#  'kalau': {'SC': 10},
#  'dikatakan': {'VB': 5},
#  'keberhasilan': {'NN': 3},
#  'mendorong': {'VB': 13},
#  'perdebatan': {'NN': 1},
#  'apa': {'SC': 2, 'WH': 3},
#  'arti': {'NN': 3},
#  'membutuhkan': {'VB': 5},
#  'kisah': {'NN': 5},
#  'pendiri': {'NN': 2},
#  'facebook': {'NNP': 5},
#  'dibuat': {'VB': 2},
#  'komik': {'NN': 3},
#  'mark': {'NNP': 3, 'FW': 1},
#  'zuckerberg': {'NNP': 6},
#  'diceritakan': {'VB': 1},
#  'sebuah': {'NND': 19},
#  'biografi': {'NN': 1},
#  'judul': {'NN': 3},
#  ':': {'Z': 5, 'NNP': 2},
#  'pencipta': {'NN': 2},
#  'tersedia': {'VB': 1},
#  'pasar': {'NN': 32, 'NNP': 6},
#  'sebelum': {'SC': 50},
#  'desember': {'NNP': 14},
#  '2010': {'CD': 4},
#  'demikian': {'PR': 25},
#  'pernyataan': {'NN': 8},
#  'penerbit': {'NNP': 1},
#  'bluewater': {'NNP': 1},
#  'productions': {'NNP': 1},
#  'penulis': {'NNP': 1},
#  'jerome': {'NNP': 1},
#  'maida': {'NNP': 1},
#  'menyebut': {'VB': 1},
#  'mengagumkan': {'VB': 1},
#  'luar biasa': {'JJ': 4},
#  'film': {'NN': 8},
#  'the': {'NNP': 24},
#  'social': {'NNP': 1},
#  'network': {'NNP': 1},
#  'dirilis': {'VB': 1},
#  'pada': {'IN': 276},
#  'tanggal': {'NN': 11},
#  '15': {'CD': 18},
#  'oktober': {'NNP': 29},
#  'nanti': {'NN': 6},
#  'ditulis': {'VB': 5},
#  'oleh': {'IN': 79},
#  'serial': {'NN': 1},
#  'west': {'NNP': 1},
#  'wing': {'NNP': 1},
#  'aaron': {'NNP': 1},
#  'sorkin': {'NNP': 1},
#  'disutradarai': {'VB': 1},
#  'david': {'NNP': 1},
#  'fincher': {'NNP': 1},
#  'pernah': {'MD': 7},
#  'menggarap': {'VB': 1},
#  'fight': {'NNP': 1},
#  "'": {'NNP': 5, 'Z': 68},
#  's': {'NNP': 8},
#  'club': {'NNP': 1},
#  'sebenarnya': {'RB': 6},
#  'memperoleh': {'VB': 2},
#  'izin': {'NN': 2},
#  'pemuda': {'NN': 1},
#  'berusia': {'VB': 7},
#  '26': {'CD': 6},
#  'saya': {'PRP': 23},
#  'mengharapkan': {'VB': 5},
#  'membuat': {'VB': 8},
#  'tentang': {'IN': 10},
#  'ketika': {'SC': 13},
#  'masih': {'MD': 61},
#  'hidup': {'VB': 1},
#  'konferensi': {'NN': 2},
#  'teknologi': {'NN': 7, 'NNP': 1},
#  'juni': {'NNP': 15},
#  'silam': {'NN': 2},
#  'hingga': {'IN': 38, 'SC': 6},
#  'juli': {'NNP': 12},
#  '500': {'CD': 5},
#  'juta': {'CD': 55},
#  'terdaftar': {'VB': 2},
#  'situs': {'NN': 5},
#  'jejaring': {'NN': 2},
#  'sosial': {'JJ': 3},
#  'hanya': {'RB': 24},
#  'butuh': {'VB': 2},
#  'enam': {'CD': 10},
#  'kesuksesan': {'NN': 4},
#  'seperti': {'SC': 2, 'IN': 21},
#  'sekarang': {'NN': 7},
#  'setelah': {'SC': 24, 'IN': 1},
#  'meluncurkan': {'VB': 1},
#  'saat': {'SC': 5, 'NN': 41},
#  'duduk': {'VB': 2},
#  'sebagai': {'IN': 38},
#  'mahasiswa': {'NN': 1},
#  'universitas': {'NNP': 2},
#  'harvard': {'NNP': 2},
#  'september': {'NNP': 17},
#  'majalah': {'NNP': 2},
#  'forbes': {'NNP': 1},
#  'memasukkan': {'VB': 2},
#  'daftar': {'NN': 2},
#  '35': {'CD': 6},
#  'serikat': {'NNP': 6},
#  'total': {'NN': 21},
#  'diperkirakan': {'VB': 22},
#  'us': {'NNP': 3},
#  '$': {'SYM': 3},
#  '6,4': {'CD': 4},
#  'miliar': {'CD': 108},
#  'langkah': {'NN': 8},
#  'menuju': {'VB': 3},
#  'lah': {'RP': 10},
#  'mulus': {'JJ': 2},
#  'rekan': {'NN': 3},
#  'mengklaim': {'VB': 4},
#  'ide': {'NN': 1},
#  'pembuatan': {'NN': 4},
#  'datang': {'VB': 3},
#  'terlibat': {'VB': 1},
#  'sengketa': {'NN': 1},
#  'hukum': {'NN': 7},
#  'berlarut-larut': {'VB': 1},
#  '2008': {'CD': 42},
#  'diakhiri': {'VB': 1},
#  'pembayaran': {'NN': 12},
#  'dirahasiakan': {'VB': 1},
#  'cameron': {'NNP': 1},
#  'tyler': {'NNP': 1},
#  'winklevoss': {'NNP': 1},
#  'kini': {'NN': 5},
#  'bernama': {'VB': 3},
#  'connectu': {'NNP': 1},
#  'perebutan': {'NN': 1},
#  'jamrud': {'NNP': 3, 'NN': 5},
#  'bahia': {'NNP': 3},
#  'raksasa': {'JJ': 4},
#  'jaksa': {'NN': 2},
#  'kalifornia': {'NNP': 2},
#  'menanyai': {'VB': 1},
#  'menentukan': {'VB': 2},
#  'kepemilikan': {'NN': 17},
#  'disebut': {'VB': 4},
#  'terbesar': {'JJ': 10},
#  'dinamakan': {'VB': 1},
#  'sesuai': {'JJ': 6},
#  'lokasi': {'NN': 1},
#  'penemuan': {'NN': 1},
#  'daerah': {'NN': 14, 'NNP': 3},
#  'brasil': {'NNP': 6},
#  'berat': {'NN': 1, 'JJ': 5},
#  '380': {'CD': 1},
#  'kg': {'NND': 2},
#  'bernilai': {'VB': 2},
#  '370': {'CD': 2},
#  'hak': {'NN': 4},
#  'atas': {'IN': 29, 'NN': 11},
#  'batu': {'NN': 5},
#  'mendengarkan': {'VB': 2},
#  'semua': {'CD': 10},
#  'permata': {'NN': 2},
#  'memutuskan': {'VB': 5},
#  'kasus': {'NN': 4},
#  'berselisih': {'VB': 1},
#  'anthony': {'NNP': 1},
#  'thomas': {'NNP': 3},
#  'ahli': {'NN': 1},
#  'konstruksi': {'NN': 6},
#  'membayar': {'VB': 5},
#  'agen': {'NN': 1},
#  'senilai': {'NN': 16},
#  '60.000': {'CD': 1},
#  'tak': {'NEG': 6},
#  'ditemukan': {'VB': 1},
#  'sembilan': {'CD': 6},
#  'lalu': {'NN': 1, 'CC': 33},
#  'mengatur': {'VB': 1},
#  'dikirim': {'VB': 2},
#  'melalui': {'IN': 20, 'VB': 1},
#  'kapal': {'NN': 6},
#  'ke': {'IN': 60},
#  'kediaman': {'NN': 1},
#  'san': {'NNP': 1},
#  'jose': {'NNP': 1},
#  'muncul': {'VB': 6},
#  'percaya': {'VB': 1},
#  'dicuri': {'VB': 1},
#  'dijual': {'VB': 3},
#  'kembali': {'RB': 26, 'VB': 5},
#  'harga': {'NN': 67, 'NNP': 2},
#  'mahal': {'JJ': 2},
#  'pemilik': {'NN': 5},
#  'satu': {'CD': 15},
#  'masalah': {'NN': 5},
#  'dihadapi': {'VB': 4},
#  'kehilangan': {'VB': 1},
#  'tanda terima': {'NN': 1},
#  'akibat': {'IN': 13, 'NN': 3},
#  'kebakaran': {'NN': 1},
#  'melanda': {'VB': 1},
#  'rumah': {'NN': 1},
#  'akhirnya': {'RB': 2},
#  'sampai': {'VB': 1, 'IN': 25, 'SC': 1},
#  'meskipun': {'SC': 5},
#  'setibanya': {'SC': 1},
#  'jelas': {'JJ': 4, 'VB': 8},
#  'siapa': {'SC': 3},
#  'hal': {'NN': 23},
#  'diketahui': {'VB': 1},
#  'sempat': {'MD': 7},
#  'disimpan': {'VB': 1},
#  'lemari besi': {'NN': 1},
#  'bank': {'NN': 29, 'NNP': 90, 'FW': 1},
#  'new': {'NNP': 8},
#  'orleans': {'NNP': 1},
#  'terkena': {'VB': 1},
#  'banjir': {'NN': 1},
#  'diterjang': {'VB': 1},
#  'badai': {'NNP': 1},
#  'katrina': {'NNP': 1},
#  'sehingga': {'SC': 32},
#  'berharga': {'JJ': 3},
#  'terendam': {'VB': 1},
#  'bulan': {'NN': 43, 'NNP': 1},
#  'kemudian': {'RB': 6, 'CC': 9, 'NN': 1},
#  'dibawa': {'VB': 1},
#  'las': {'NNP': 1},
#  'vegas': {'NNP': 1},
#  'dilihat': {'VB': 3},
#  'calon': {'NN': 5},
#  'pembeli': {'NN': 1},
#  'namun': {'CC': 52},
#  'disita': {'VB': 1},
#  'polisi': {'NN': 3},
#  'los': {'NNP': 1},
#  'angeles': {'NNP': 1},
#  'badut': {'NN': 3},
#  'politikus': {'NN': 2},
#  'ditantang': {'VB': 2},
#  'baca': {'VB': 2},
#  'tulis': {'VB': 2},
#  'mempunyai': {'VB': 7},
#  'peluang': {'NN': 5},
#  'meraih': {'VB': 9},
#  'kursi': {'NN': 5},
#  'pemilihan': {'NN': 4},
#  'minggu': {'NNP': 3, 'NN': 1},
#  '(': {'Z': 5},
#  '3': {'CD': 11},
#  '/': {'Z': 37, 'NNP': 15},
#  ')': {'Z': 5},
#  '-': {'Z': 99, 'NNP': 15},
#  'membuktikan': {'VB': 3},
#  'membaca': {'VB': 6},
#  'menulis': {'VB': 1},
#  'jajak': {'NN': 1},
#  'pendapat': {'NN': 1},
#  'memperlihatkan': {'VB': 6},
#  'tiririca': {'NNP': 5},
#  'suara': {'NN': 4},
#  'hakim': {'NN': 2},
#  'sao': {'NNP': 1},
#  'paulo': {'NNP': 1},
#  'menuntut': {'VB': 1},
#  'memenuhi': {'VB': 6},
#  'persyaratan': {'NN': 2},
#  'surat kabar': {'NN': 1},
#  'sama': {'JJ': 35},
#  'sepuluh': {'CD': 5},
#  'buta aksara': {'JJ': 1},
#  'bahasa sehari-hari': {'NN': 1},
#  'portugis': {'NNP': 1},
#  'tukang': {'NN': 1},
#  'mengeluh': {'VB': 1},
#  'sensasi': {'NN': 1},
#  'kampanye': {'NN': 2},
#  'video': {'NN': 2},
#  'kocak': {'JJ': 1},
#  'jutaan': {'CD': 1},
#  'penonton': {'NN': 3},
#  'youtube': {'NNP': 6},
#  'antara': {'IN': 22, 'NN': 5, 'NNP': 3},
#  'menggunakan': {'VB': 11},
#  'slogan': {'NN': 1},
#  'buruk': {'JJ': 2},
#  'lagi': {'RB': 12},
#  'dilakukan': {'VB': 26},
#  'wakil': {'NN': 1, 'NNP': 5},
#  'anda': {'PRP': 2},
#  '?': {'Z': 2},
#  'sungguh': {'RB': 2},
#  'tahu': {'VB': 6},
#  'tapi': {'CC': 11},
#  'pilih': {'VB': 1},
#  'mencari tahu': {'VB': 1},
#  'menggelar': {'VB': 1},
#  'ujian': {'NN': 1},
#  'aksara': {'NN': 1},
#  'epoca': {'NNP': 1},
#  'menayangkan': {'VB': 1},
#  'tampak': {'VB': 6},
#  'komisi': {'NN': 1, 'NNP': 8},
#  'terlambat': {'VB': 1},
#  'menghentikan': {'VB': 4},
#  'pencalonan': {'NN': 1},
#  'diberhentikan': {'VB': 1},
#  'jika': {'SC': 10},
#  'gagal': {'VB': 2},
#  'kemampuan': {'NN': 6},
#  'selebriti': {'NN': 3},
#  'nama': {'NN': 2},
#  'asli': {'JJ': 6},
#  'francisco': {'NNP': 1},
#  'everardo': {'NNP': 1},
#  'oliveira': {'NNP': 1},
#  'silva': {'NNP': 1},
#  'bekerja': {'VB': 5},
#  'sirkus': {'NN': 1},
#  'delapan': {'CD': 1},
#  'miskin': {'JJ': 1},
#  'ceara': {'NNP': 1},
#  'pengalaman': {'NN': 1},
#  'salah seorang': {'CD': 3},
#  'pelawak': {'NN': 1},
#  'terkenal': {'VB': 3},
#  'tv': {'NN': 5},
#  'merupakan': {'VB': 32},
#  'puluhan': {'CD': 1},
#  'berasal': {'VB': 10},
#  'olahraga': {'NN': 5},
#  'maupun': {'CC': 14},
#  'pertunjukan': {'NN': 1},
#  'berjuang': {'VB': 1},
#  'merebut': {'VB': 2},
#  'majelis rendah': {'NN': 1},
#  'bersaing': {'VB': 1},
#  'melawan': {'VB': 1},
#  'berpengalaman': {'VB': 1},
#  'seluruhnya': {'RB': 1},
#  'tercatat': {'VB': 11},
#  '6.000': {'CD': 1},
#  '27': {'CD': 3},
#  'partai': {'NN': 1, 'NNP': 1},
#  '513': {'CD': 1},
#  'diduga': {'VB': 2},
#  'kemenangan': {'NN': 2},
#  'mutlak': {'JJ': 1},
#  'romario': {'NNP': 1},
#  'bintang': {'NN': 3, 'NNP': 1},
#  'sepak bola': {'NN': 2},
#  'piala': {'NNP': 3},
#  '1994': {'CD': 2},
#  'pengamat': {'NN': 2},
#  'popularitas': {'NN': 1},
#  'mencerminkan': {'VB': 5},
#  'kebingungan': {'NN': 1},
#  'politik': {'NN': 1},
#  'utama': {'JJ': 9, 'NNP': 10},
#  'marak': {'JJ': 1},
#  'skandal': {'NN': 1},
#  'korupsi': {'NN': 4},
#  'ibu': {'NN': 1},
#  'bayi': {'NN': 2},
#  'anggota': {'NN': 6},
#  'eropa': {'NNP': 4},
#  'asal': {'IN': 2},
#  'italia': {'NNP': 2},
#  'sidang': {'NN': 4, 'NNP': 1},
#  'strasbourg': {'NNP': 1},
#  'menggendong': {'VB': 1},
#  'anak': {'NN': 7},
#  'licia': {'NNP': 1},
#  'ronzulli': {'NNP': 2},
#  'ia': {'PRP': 38},
#  'menunjukkan': {'VB': 19},
#  'beban': {'NN': 3},
#  'ditanggung': {'VB': 1},
#  'kaum': {'NN': 1},
#  'perempuan': {'NN': 2},
#  'menjalani': {'VB': 1},
#  'karir': {'NN': 1},
#  'sekaligus': {'RB': 4},
#  'mengasuh': {'VB': 1},
#  'sedang': {'MD': 8},
#  'membahas': {'VB': 3},
#  'usul': {'NN': 1},
#  'memperbaiki': {'VB': 9},
#  'kesempatan': {'NN': 6},
#  'vittoria': {'NNP': 1},
#  'tidur': {'VB': 1},
#  'nyenyak': {'JJ': 1},
#  'berlangsung': {'VB': 9},
#  'mewakili': {'VB': 2},
#  'kebebasan': {'NNP': 1},
#  'rakyat': {'NNP': 1, 'NN': 9},
#  'pimpinan': {'NN': 2, 'NNP': 1},
#  'pm': {'NNP': 5},
#  'silvio': {'NNP': 1},
#  'berlusconi': {'NNP': 1},
#  'mendapat': {'VB': 8},
#  'sambutan': {'NN': 1},
#  'meriah': {'JJ': 1},
#  'berdiri': {'VB': 1},
#  'menyampaikan': {'VB': 5},
#  'pidato': {'NN': 7},
#  'sesama': {'NN': 1},
#  'melihat': {'VB': 10},
#  'komitmen': {'NN': 4},
#  'persoalan-persoalan': {'NN': 1},
#  'lembaga-lembaga': {'NN': 1},
#  'dimulai': {'VB': 2},
#  'naskah': {'NN': 6},
#  'harry': {'NNP': 3},
#  'potter': {'NNP': 3},
#  'dipamerkan': {'VB': 4},
#  'tangan': {'NN': 1},
#  'pengarang': {'NN': 2},
#  'jk': {'NNP': 3},
#  'rowling': {'NNP': 3},
#  'festival': {'NN': 3, 'NNP': 1},
#  'buku': {'NN': 5},
#  'skotlandia': {'NNP': 3},
#  'selatan': {'NNP': 6},
#  'halaman': {'NND': 1, 'NN': 5},
#  'dibingkai': {'VB': 1},
#  'ditandatangani': {'VB': 2},
#  'berisi': {'VB': 1},
#  'balada': {'NN': 2},
#  'nick': {'NNP': 3},
#  'si': {'DT': 4},
#  'kepala': {'NN': 9, 'NNP': 5},
#  'nyaris': {'RB': 2},
#  'putus': {'VB': 2},
#  'wigtown': {'NNP': 2},
#  '24': {'CD': 6},
#  'hantu': {'NN': 1},
#  'awal': {'NN': 18},
#  'kamar': {'NN': 1},
#  'rahasia': {'NN': 1},
#  'dibuang': {'VB': 1},
#  'termasuk': {'VB': 19},
#  'diterbitkan': {'VB': 11},
#  'disumbangkan': {'VB': 2},
#  'yayasan': {'NNP': 1},
#  'kamus': {'NNP': 1, 'NN': 1},
#  'bahasa': {'NNP': 5, 'NN': 1},
#  '2005': {'CD': 16},
#  'mendukung': {'VB': 9},
#  'pengumpulan': {'NN': 1},
#  'dana': {'NN': 31, 'NNP': 2},
#  'dimiliki': {'VB': 8},
#  'kolektor': {'NN': 1},
#  'terkemuka': {'JJ': 1},
#  'inggris': {'NNP': 15},
#  'jurnal': {'NNP': 1},
#  'asia': {'NNP': 11},
#  'literary': {'NNP': 2},
#  'review': {'NNP': 2},
#  'ilyas': {'NNP': 2},
#  'khan': {'NNP': 2},
#  'senang': {'JJ': 1},
#  'ikut': {'VB': 2},
#  'memamerkan': {'VB': 1},
#  'cara': {'NN': 5},
#  'bagus': {'JJ': 4},
#  'australia': {'NNP': 6},
#  'salah': {'JJ': 2},
#  'sebut': {'VB': 1},
#  'pemenang': {'NN': 7},
#  'next': {'NNP': 1},
#  'top': {'NNP': 1, 'JJ': 3},
#  'model': {'NNP': 1, 'NN': 2},
#  'mengumumkan': {'VB': 4},
#  'final': {'NN': 3},
#  'disiarkan': {'VB': 1},
#  'langsung': {'RB': 12},
#  'seri': {'NN': 9, 'NNP': 3},
#  'keenam': {'OD': 3},
#  'kelsey': {'NNP': 1},
#  'martinovich': {'NNP': 2},
#  'dianugerahi': {'VB': 1},
#  'mahkota': {'NN': 1},
#  'pilihan': {'NN': 1},
#  'pemirsa': {'NN': 1},
#  'presenter': {'NNP': 1, 'FW': 1},
#  'sarah': {'NNP': 4},
#  'murdoch': {'NNP': 4},
#  'menyela': {'VB': 1},
#  'sambil': {'SC': 1},
#  'menggeleng-gelengkan': {'VB': 1},
#  'ear': {'FW': 1},
#  'piece': {'FW': 1},
#  'mual': {'JJ': 1},
#  'amat': {'RB': 1},
#  'meminta': {'VB': 8},
#  'maaf': {'NN': 1},
#  'semata-mata': {'RB': 2},
#  'kecelakaan': {'NN': 1},
#  'yaitu': {'SC': 19},
#  'amanda': {'NNP': 2},
#  'ware': {'NNP': 2},
#  '18': {'CD': 8},
#  'terjadi': {'VB': 28},
#  'siaran': {'NN': 1},
#  'edan': {'JJ': 3},
#  'adapun': {'CC': 1},
#  'sekitar': {'RB': 35, 'IN': 6, 'NN': 1},
#  'menit': {'NND': 1, 'NN': 2},
#  'menerima': {'VB': 5},
#  'kesalahan': {'NN': 1},
#  'baik': {'JJ': 28, 'CC': 4},
#  'ok': {'FW': 1},
#  'kekeliruan': {'NN': 2},
#  'berusaha': {'VB': 3},
#  'menjelaskan': {'VB': 13},
#  'selisih': {'NN': 3},
#  'ketat': {'JJ': 4},
#  'memimpin': {'VB': 1},
#  'terus-menerus': {'RB': 1},
#  'berganti': {'VB': 1},
#  'benar-benar': {'RB': 2},
#  'tergantung': {'VB': 3},
#  'maju': {'VB': 1, 'JJ': 2},
#  'mundur': {'VB': 1},
#  'finalis': {'NN': 1},
#  'berpelukan': {'VB': 1},
#  'mengucapkan': {'VB': 1},
#  'terima kasih': {'NN': 1},
#  'pendukung': {'NN': 2},
#  'berjalan': {'VB': 10},
#  'catwalk': {'FW': 1},
#  'kali': {'NND': 6, 'NN': 4},
#  'merangkap': {'VB': 1},
#  'menikah': {'VB': 1},
#  'putra': {'NN': 1, 'NNP': 1},
#  'rupert': {'NNP': 1},
#  'lachlan': {'NNP': 1},
#  'don': {'NNP': 3},
#  'quixote': {'NNP': 3},
#  'akademi': {'NNP': 2, 'NN': 1},
#  'kerajaan': {'NNP': 4},
#  'spanyol': {'NNP': 7},
#  'mengundang': {'VB': 1},
#  'merekam': {'VB': 1},
#  'segmen': {'NN': 8},
#  'novel': {'NN': 5},
#  'klasik': {'JJ': 2},
#  'mengunggah': {'VB': 1},
#  'karya': {'NN': 4, 'NNP': 1},
#  'miguel': {'NNP': 1},
#  'de': {'NNP': 1},
#  'cervantes': {'NNP': 1},
#  'paling': {'RB': 6},
#  'populer': {'JJ': 1},
#  'walau': {'SC': 2},
#  'pelindung': {'NN': 1},
#  'membagi': {'VB': 1},
#  '2.000': {'CD': 2},
#  'segmen-segmen': {'NN': 1},
#  'dibaca': {'VB': 1},
#  'direkam': {'VB': 1},
#  'sukarelawan': {'NN': 1},
#  'diunggah': {'VB': 2},
#  'tujuan': {'NN': 6},
#  'mempromosikan': {'VB': 1},
#  'lengkap': {'JJ': 2},
#  'ingenious': {'NNP': 1},
#  'hidalgo': {'NNP': 1},
#  'of': {'NNP': 8, 'FW': 2},
#  'la': {'NNP': 2},
#  'mancha': {'NNP': 2},
#  'ruang': {'NN': 2},
#  'sepatutnya': {'RB': 1},
#  'internet': {'NN': 1},
#  'sekretaris': {'NN': 1, 'NNP': 12},
#  'dario': {'NNP': 1},
#  'villanueva': {'NNP': 1},
#  'mengadukan': {'VB': 1},
#  'melakukan': {'VB': 30},
#  'sesuatu': {'PRP': 3},
#  'mengoreksi': {'VB': 1},
#  '1605': {'CD': 1},
#  'berkisah': {'VB': 1},
#  'petualangan': {'NN': 1},
#  'pria': {'NN': 3},
#  'pensiunan': {'NN': 1},
#  'kawasan': {'NN': 3},
#  'punya': {'VB': 2},
#  'obsesi': {'NN': 1},
#  'gagasan-gagasan': {'NN': 1},
#  'kesatria': {'NN': 1},
#  'terdiri': {'VB': 16},
#  'bab': {'NN': 1},
#  'hampir': {'RB': 3},
#  '1.000': {'CD': 2},
#  'berminat': {'VB': 1},
#  'mendaftarkan': {'VB': 1},
#  'terpilih': {'VB': 1},
#  'tertentu': {'JJ': 4},
#  'hobbit': {'NNP': 3},
#  'cari': {'VB': 1},
#  'aktor': {'NN': 6},
#  'kerdil': {'JJ': 2},
#  'tim': {'NN': 5, 'NNP': 1},
#  'pembuat': {'NN': 2},
#  'mencari': {'VB': 5},
#  'selandia': {'NNP': 2},
#  'sementara': {'SC': 27, 'CC': 22, 'RB': 3},
#  'sutradara': {'NNP': 2, 'NN': 4},
#  'peter': {'NNP': 2},
#  'jackson': {'NNP': 3},
#  'berancang-ancang': {'VB': 1},
#  'merealisasikan': {'VB': 1},
#  'rencana': {'NN': 32},
#  'oscar': {'NNP': 2},
#  'lord': {'NNP': 3},
#  'rings': {'NNP': 3},
#  'return': {'NNP': 2},
#  'king': {'NNP': 3},
#  'iklan': {'NN': 2},
#  'koran': {'NN': 1},
#  'terbitan': {'NN': 1},
#  'wellington': {'NNP': 2},
#  'wingnut': {'NNP': 2},
#  'films': {'NNP': 1},
#  'badan': {'NN': 8, 'NNP': 10},
#  '123': {'CD': 1},
#  'cm': {'NND': 5},
#  'maksimum': {'NN': 2},
#  '158': {'CD': 1},
#  'proyek': {'NN': 12},
#  'lampu hijau': {'NN': 1},
#  'perusahaan': {'NN': 70, 'NNP': 14},
#  'perfilman': {'NN': 1},
#  'mgm': {'NNP': 1},
#  'studios': {'NNP': 1},
#  'keuangan': {'NN': 40, 'NNP': 21},
#  'tengah': {'MD': 5, 'NN': 3},
#  'dialami': {'VB': 1},
#  'juru bicara': {'NNP': 1, 'NN': 3},
#  'bersiap-siap': {'VB': 1},
#  'scale': {'FW': 2},
#  'double': {'FW': 3},
#  'mengisi': {'VB': 2},
#  'peran': {'NN': 3},
#  'dialog': {'NN': 3},
#  'sedangkan': {'CC': 41},
#  'audisi': {'NN': 1},
#  'diadakan': {'VB': 2},
#  'figuran': {'NN': 1},
#  'wide': {'FW': 1},
#  'shot': {'FW': 1},
#  'pengganti': {'NN': 1},
#  'dewasa': {'JJ': 2},
#  'memerlukan': {'VB': 5},
#  'terlihat': {'VB': 3},
#  'atau': {'CC': 91},
#  'menambahkan': {'VB': 17},
#  'pelamar': {'NN': 1},
#  '16': {'CD': 3},
#  'siapa pun': {'SC': 1},
#  'ketentuan': {'NN': 7},
#  'ditolak': {'VB': 1},
#  'berkaki': {'VB': 1},
#  'pendek': {'JJ': 3},
#  'meski': {'SC': 22},
#  'syarat': {'NN': 1},
#  'layak': {'JJ': 1},
#  'dipilih': {'VB': 1},
#  'jangkung': {'JJ': 1},
#  'karakter': {'NN': 1},
#  'fiksi': {'NN': 1},
#  'ciptaan': {'NN': 1},
#  'jrr': {'NNP': 1},
#  'tolkien': {'NNP': 1},
#  'prolog': {'NN': 1},
#  'menggambarkan': {'VB': 3},
#  'hobbits': {'NNP': 2},
#  'berukuran': {'VB': 1},
#  'tiga': {'CD': 17},
#  'kaki': {'NND': 4, 'NN': 3},
#  '60': {'CD': 6},
#  '120': {'CD': 2},
#  'rata-rata': {'NN': 18, 'JJ': 14},
#  'inci': {'NND': 1},
#  '75': {'CD': 4},
#  'surat-surat': {'NN': 1},
#  'penampakan': {'NN': 1},
#  'fisik': {'NN': 1},
#  'sosok': {'NN': 1},
#  'protagonis': {'NN': 1},
#  'bilbo': {'NNP': 1},
#  'baggins': {'NNP': 1},
#  'agak': {'RB': 5},
#  'tambun': {'JJ': 1},
#  'perut': {'NN': 1},
#  'bulat': {'JJ': 1},
#  'jenaka': {'JJ': 1},
#  ';': {'Z': 6},
#  'telinga': {'NN': 1},
#  'sedikit': {'RB': 3, 'JJ': 3, 'MD': 1, 'CD': 1},
#  'runcing': {'JJ': 1},
#  'kurcaci': {'NN': 1},
#  'rambut': {'NN': 1},
#  'keriting': {'JJ': 1},
#  'cokelat': {'JJ': 2},
#  'mata kaki': {'NN': 1},
#  'bawah': {'NN': 4},
#  'tertutup': {'VB': 1},
#  'bulu': {'NN': 1},
#  'tambah': {'VB': 10},
#  'pencarian': {'NN': 1},
#  'casting': {'FW': 1},
#  'dijadwalkan': {'VB': 1},
#  'hari': {'NN': 15},
#  'national': {'NNP': 2, 'FW': 1},
#  'dance': {'NNP': 1},
#  'and': {'NNP': 5, 'FW': 3},
#  'drama': {'NNP': 1},
#  'centre': {'NNP': 1},
#  'kelahiran': {'NN': 1},
#  'meksiko': {'NNP': 1},
#  'guillermo': {'NNP': 1},
#  'del': {'NNP': 1},
#  'toro': {'NNP': 1},
#  'bersedia': {'VB': 1},
#  'menarik diri': {'VB': 1},
#  'alasan': {'NN': 1},
#  'produksi': {'NN': 31},
#  'tertunda': {'VB': 1},
#  'terbaik': {'JJ': 4},
#  'menggantikan': {'VB': 3},
#  'pengumuman': {'NN': 2},
#  'pergantian': {'NN': 1},
#  'pencurian': {'NN': 3},
#  'ladang': {'NN': 4},
#  'anggur': {'NN': 9},
#  'pencuri': {'NN': 2},
#  'prancis': {'NNP': 2},
#  'masuk': {'VB': 9},
#  'mencuri': {'VB': 3},
#  'panenan': {'NN': 1},
#  'cabernet': {'NNP': 1},
#  'sauvignon': {'NNP': 1},
#  'aksi': {'NN': 5},
#  'villeneuve': {'NNP': 1},
#  'les-beziers': {'NNP': 1},
#  'malam': {'NN': 4},
#  '9': {'CD': 9},
#  'memanfaatkan': {'VB': 1},
#  'terang bulan': {'JJ': 1},
#  'ton': {'NND': 31},
#  'mesin': {'NN': 9, 'NNP': 1},
#  'petani': {'NNP': 1},
#  ...}

# %%
#Memilih tag yang terbesar untukk setiap kata
import operator
def baseline(word_tags):
    baseline = {}
    for key, value in word_tags.items():
        baseline[key] = max(value.items(), key=operator.itemgetter(1))[0]
    return baseline
max_frekuensi_tag = baseline(word_tag)
print("Kata dan postag berdasarkan frekuensi terbanyak :")
print("-------------------------------------------------")
max_frekuensi_tag
# Out:
# Kata dan postag berdasarkan frekuensi terbanyak :
# -------------------------------------------------
# {'kera': 'NN',
#  'untuk': 'SC',
#  'amankan': 'VB',
#  'pesta olahraga': 'NN',
#  'pemerintah': 'NN',
#  'kota': 'NNP',
#  'delhi': 'NNP',
#  'mengerahkan': 'VB',
#  'monyet': 'NN',
#  'mengusir': 'VB',
#  'monyet-monyet': 'NN',
#  'lain': 'JJ',
#  'yang': 'SC',
#  'berbadan': 'VB',
#  'lebih': 'RB',
#  'kecil': 'JJ',
#  'dari': 'IN',
#  'arena': 'NN',
#  'persemakmuran': 'NNP',
#  '.': 'Z',
#  'beberapa': 'CD',
#  'laporan': 'NN',
#  'menyebutkan': 'VB',
#  'setidaknya': 'RB',
#  '10': 'CD',
#  'ditempatkan': 'VB',
#  'di': 'IN',
#  'luar': 'NN',
#  'lomba': 'NN',
#  'dan': 'CC',
#  'pertandingan': 'NN',
#  'ibukota': 'NNP',
#  'india': 'NNP',
#  'pemkot': 'NNP',
#  'memiliki': 'VB',
#  '28': 'CD',
#  'berencana': 'VB',
#  'mendatangkan': 'VB',
#  'sejenis': 'NN',
#  'negara bagian': 'NNP',
#  'rajasthan': 'NNP',
#  'jumlah': 'NN',
#  'mencapai': 'VB',
#  'ribuan': 'CD',
#  ',': 'Z',
#  'sebagian besar': 'NN',
#  'berada': 'VB',
#  'kantor-kantor': 'NN',
#  'hewan': 'NN',
#  'ini': 'PR',
#  'dianggap': 'VB',
#  'mengganggu': 'VB',
#  'ketertiban': 'NN',
#  'umum': 'JJ',
#  'jenis': 'NN',
#  'dikerahkan': 'VB',
#  'besar': 'JJ',
#  'berekor': 'VB',
#  'panjang': 'JJ',
#  'wajah': 'NN',
#  'berwarna': 'VB',
#  'hitam': 'JJ',
#  'diikat': 'VB',
#  'dengan': 'IN',
#  'tali': 'NN',
#  'pelatih': 'NN',
#  'mengawasi': 'VB',
#  'mereka': 'PRP',
#  'akan': 'MD',
#  'melepas': 'VB',
#  'begitu': 'PR',
#  'mendekat': 'VB',
#  'kantor': 'NNP',
#  'berita': 'NNP',
#  'afp': 'NNP',
#  'melaporkan': 'VB',
#  'stadion': 'NN',
#  'tinju': 'NN',
#  'hockey': 'FW',
#  'mendapatkan': 'VB',
#  'perhatian': 'NN',
#  'khusus': 'JJ',
#  'karena': 'SC',
#  'sering': 'RB',
#  'diserbu': 'VB',
#  'dua': 'CD',
#  'serbuan': 'NN',
#  '"': 'Z',
#  'tersebut': 'PR',
#  'kata': 'VB',
#  'devender': 'NNP',
#  'prasad': 'NNP',
#  'pejabat': 'NN',
#  'kepada': 'IN',
#  'kantor berita': 'NNP',
#  'selama': 'IN',
#  'bertahun-tahun': 'CD',
#  'warga': 'NN',
#  'binatang': 'NN',
#  'menaiki': 'VB',
#  'kereta': 'NN',
#  'metro': 'NN',
#  'bahkan': 'RB',
#  'berkeliaran': 'VB',
#  'kompleks': 'NN',
#  'gedung': 'NNP',
#  'parlemen': 'NN',
#  'belum': 'NEG',
#  'lama': 'JJ',
#  'kawanan': 'NN',
#  'menyerbu': 'VB',
#  'perdana menteri': 'NN',
#  'departemen': 'NNP',
#  'pertahanan': 'NN',
#  'tidak': 'NEG',
#  'bisa': 'MD',
#  'dibunuh': 'VB',
#  'masyarakat': 'NN',
#  'menganggap': 'VB',
#  'suci': 'JJ',
#  'selain': 'IN',
#  'harus': 'MD',
#  'juga': 'RB',
#  'kesulitan': 'VB',
#  'mengatasi': 'VB',
#  'wabah': 'NN',
#  'demam berdarah': 'NN',
#  'curah': 'NN',
#  'hujan': 'NN',
#  'tinggi': 'JJ',
#  'menyebabkan': 'VB',
#  'banyak': 'CD',
#  'genangan': 'NN',
#  'tempat': 'NN',
#  'ideal': 'JJ',
#  'bagi': 'IN',
#  'nyamuk': 'NN',
#  'aedes': 'NNP',
#  'berkembang biak': 'VB',
#  'telah': 'MD',
#  'menempatkan': 'VB',
#  'ikan': 'NN',
#  'berbagai': 'CD',
#  'air': 'NN',
#  'memangsa': 'VB',
#  'telur': 'NN',
#  'miliarder': 'NN',
#  'as': 'NNP',
#  'jamu': 'VB',
#  'orang kaya': 'NN',
#  'cina': 'NNP',
#  'amerika': 'NNP',
#  'bill': 'NNP',
#  'gates': 'NNP',
#  'warren': 'NNP',
#  'buffett': 'NNP',
#  'mengadakan': 'VB',
#  'jamuan': 'NN',
#  'makan malam': 'NN',
#  'beijing': 'NNP',
#  'sejumlah': 'CD',
#  'orang': 'NN',
#  'terkaya': 'JJ',
#  'mengatakan': 'VB',
#  'mempelajari': 'VB',
#  'kegiatan': 'NN',
#  'amal': 'NN',
#  'negara': 'NN',
#  'itu': 'PR',
#  'menduga': 'VB',
#  'ingin': 'RB',
#  'membujuk': 'VB',
#  'para': 'DT',
#  'tamu': 'NN',
#  'agar': 'SC',
#  'menyumbang': 'VB',
#  'kedua': 'CD',
#  'dunia': 'NN',
#  'sudah': 'MD',
#  'berhasil': 'VB',
#  'sangat': 'RB',
#  'kaya': 'JJ',
#  'menyumbangkan': 'VB',
#  'separuh': 'CD',
#  'kekayaan': 'NN',
#  'ada': 'VB',
#  'kerahasiaan': 'NN',
#  'mengenai': 'IN',
#  'acara': 'NN',
#  'pihak': 'NN',
#  'penyelenggara': 'NN',
#  'membeberkan': 'VB',
#  'nama-nama': 'NN',
#  'salah satu': 'CD',
#  'menghadiri': 'VB',
#  'adalah': 'VB',
#  'chen': 'NNP',
#  'guangbiao': 'NNP',
#  'seorang': 'NND',
#  'meraup': 'VB',
#  'bisnis': 'NN',
#  'mendaur ulang': 'VB',
#  'sampah': 'NN',
#  'industri': 'NN',
#  'bangunan': 'NN',
#  'dia': 'PRP',
#  'bbc': 'NNP',
#  'bahwa': 'SC',
#  'seluruh': 'CD',
#  'harta': 'NN',
#  '-nya': 'PRP',
#  'bila': 'SC',
#  'meninggal': 'VB',
#  'beramal': 'VB',
#  'membantu': 'VB',
#  'menjadi': 'VB',
#  'bagian': 'NN',
#  'budaya': 'NN',
#  '5.000': 'CD',
#  'tahun': 'NN',
#  'tetapi': 'CC',
#  'resmi': 'JJ',
#  'baru': 'JJ',
#  'dikembangkan': 'VB',
#  'dalam': 'IN',
#  '30': 'CD',
#  'terakhir': 'JJ',
#  'sejak': 'IN',
#  'kami': 'PRP',
#  'menerapkan': 'VB',
#  'reformasi ekonomi': 'NN',
#  'mulai': 'MD',
#  'baru-baru ini': 'RB',
#  'saja': 'RB',
#  'memberi': 'VB',
#  'makan': 'VB',
#  'diri': 'NN',
#  'sendiri': 'NN',
#  'uang': 'NN',
#  'berkembang': 'VB',
#  'sebaik': 'JJ',
#  'kalau': 'SC',
#  'dikatakan': 'VB',
#  'keberhasilan': 'NN',
#  'mendorong': 'VB',
#  'perdebatan': 'NN',
#  'apa': 'WH',
#  'arti': 'NN',
#  'membutuhkan': 'VB',
#  'kisah': 'NN',
#  'pendiri': 'NN',
#  'facebook': 'NNP',
#  'dibuat': 'VB',
#  'komik': 'NN',
#  'mark': 'NNP',
#  'zuckerberg': 'NNP',
#  'diceritakan': 'VB',
#  'sebuah': 'NND',
#  'biografi': 'NN',
#  'judul': 'NN',
#  ':': 'Z',
#  'pencipta': 'NN',
#  'tersedia': 'VB',
#  'pasar': 'NN',
#  'sebelum': 'SC',
#  'desember': 'NNP',
#  '2010': 'CD',
#  'demikian': 'PR',
#  'pernyataan': 'NN',
#  'penerbit': 'NNP',
#  'bluewater': 'NNP',
#  'productions': 'NNP',
#  'penulis': 'NNP',
#  'jerome': 'NNP',
#  'maida': 'NNP',
#  'menyebut': 'VB',
#  'mengagumkan': 'VB',
#  'luar biasa': 'JJ',
#  'film': 'NN',
#  'the': 'NNP',
#  'social': 'NNP',
#  'network': 'NNP',
#  'dirilis': 'VB',
#  'pada': 'IN',
#  'tanggal': 'NN',
#  '15': 'CD',
#  'oktober': 'NNP',
#  'nanti': 'NN',
#  'ditulis': 'VB',
#  'oleh': 'IN',
#  'serial': 'NN',
#  'west': 'NNP',
#  'wing': 'NNP',
#  'aaron': 'NNP',
#  'sorkin': 'NNP',
#  'disutradarai': 'VB',
#  'david': 'NNP',
#  'fincher': 'NNP',
#  'pernah': 'MD',
#  'menggarap': 'VB',
#  'fight': 'NNP',
#  "'": 'Z',
#  's': 'NNP',
#  'club': 'NNP',
#  'sebenarnya': 'RB',
#  'memperoleh': 'VB',
#  'izin': 'NN',
#  'pemuda': 'NN',
#  'berusia': 'VB',
#  '26': 'CD',
#  'saya': 'PRP',
#  'mengharapkan': 'VB',
#  'membuat': 'VB',
#  'tentang': 'IN',
#  'ketika': 'SC',
#  'masih': 'MD',
#  'hidup': 'VB',
#  'konferensi': 'NN',
#  'teknologi': 'NN',
#  'juni': 'NNP',
#  'silam': 'NN',
#  'hingga': 'IN',
#  'juli': 'NNP',
#  '500': 'CD',
#  'juta': 'CD',
#  'terdaftar': 'VB',
#  'situs': 'NN',
#  'jejaring': 'NN',
#  'sosial': 'JJ',
#  'hanya': 'RB',
#  'butuh': 'VB',
#  'enam': 'CD',
#  'kesuksesan': 'NN',
#  'seperti': 'IN',
#  'sekarang': 'NN',
#  'setelah': 'SC',
#  'meluncurkan': 'VB',
#  'saat': 'NN',
#  'duduk': 'VB',
#  'sebagai': 'IN',
#  'mahasiswa': 'NN',
#  'universitas': 'NNP',
#  'harvard': 'NNP',
#  'september': 'NNP',
#  'majalah': 'NNP',
#  'forbes': 'NNP',
#  'memasukkan': 'VB',
#  'daftar': 'NN',
#  '35': 'CD',
#  'serikat': 'NNP',
#  'total': 'NN',
#  'diperkirakan': 'VB',
#  'us': 'NNP',
#  '$': 'SYM',
#  '6,4': 'CD',
#  'miliar': 'CD',
#  'langkah': 'NN',
#  'menuju': 'VB',
#  'lah': 'RP',
#  'mulus': 'JJ',
#  'rekan': 'NN',
#  'mengklaim': 'VB',
#  'ide': 'NN',
#  'pembuatan': 'NN',
#  'datang': 'VB',
#  'terlibat': 'VB',
#  'sengketa': 'NN',
#  'hukum': 'NN',
#  'berlarut-larut': 'VB',
#  '2008': 'CD',
#  'diakhiri': 'VB',
#  'pembayaran': 'NN',
#  'dirahasiakan': 'VB',
#  'cameron': 'NNP',
#  'tyler': 'NNP',
#  'winklevoss': 'NNP',
#  'kini': 'NN',
#  'bernama': 'VB',
#  'connectu': 'NNP',
#  'perebutan': 'NN',
#  'jamrud': 'NN',
#  'bahia': 'NNP',
#  'raksasa': 'JJ',
#  'jaksa': 'NN',
#  'kalifornia': 'NNP',
#  'menanyai': 'VB',
#  'menentukan': 'VB',
#  'kepemilikan': 'NN',
#  'disebut': 'VB',
#  'terbesar': 'JJ',
#  'dinamakan': 'VB',
#  'sesuai': 'JJ',
#  'lokasi': 'NN',
#  'penemuan': 'NN',
#  'daerah': 'NN',
#  'brasil': 'NNP',
#  'berat': 'JJ',
#  '380': 'CD',
#  'kg': 'NND',
#  'bernilai': 'VB',
#  '370': 'CD',
#  'hak': 'NN',
#  'atas': 'IN',
#  'batu': 'NN',
#  'mendengarkan': 'VB',
#  'semua': 'CD',
#  'permata': 'NN',
#  'memutuskan': 'VB',
#  'kasus': 'NN',
#  'berselisih': 'VB',
#  'anthony': 'NNP',
#  'thomas': 'NNP',
#  'ahli': 'NN',
#  'konstruksi': 'NN',
#  'membayar': 'VB',
#  'agen': 'NN',
#  'senilai': 'NN',
#  '60.000': 'CD',
#  'tak': 'NEG',
#  'ditemukan': 'VB',
#  'sembilan': 'CD',
#  'lalu': 'CC',
#  'mengatur': 'VB',
#  'dikirim': 'VB',
#  'melalui': 'IN',
#  'kapal': 'NN',
#  'ke': 'IN',
#  'kediaman': 'NN',
#  'san': 'NNP',
#  'jose': 'NNP',
#  'muncul': 'VB',
#  'percaya': 'VB',
#  'dicuri': 'VB',
#  'dijual': 'VB',
#  'kembali': 'RB',
#  'harga': 'NN',
#  'mahal': 'JJ',
#  'pemilik': 'NN',
#  'satu': 'CD',
#  'masalah': 'NN',
#  'dihadapi': 'VB',
#  'kehilangan': 'VB',
#  'tanda terima': 'NN',
#  'akibat': 'IN',
#  'kebakaran': 'NN',
#  'melanda': 'VB',
#  'rumah': 'NN',
#  'akhirnya': 'RB',
#  'sampai': 'IN',
#  'meskipun': 'SC',
#  'setibanya': 'SC',
#  'jelas': 'VB',
#  'siapa': 'SC',
#  'hal': 'NN',
#  'diketahui': 'VB',
#  'sempat': 'MD',
#  'disimpan': 'VB',
#  'lemari besi': 'NN',
#  'bank': 'NNP',
#  'new': 'NNP',
#  'orleans': 'NNP',
#  'terkena': 'VB',
#  'banjir': 'NN',
#  'diterjang': 'VB',
#  'badai': 'NNP',
#  'katrina': 'NNP',
#  'sehingga': 'SC',
#  'berharga': 'JJ',
#  'terendam': 'VB',
#  'bulan': 'NN',
#  'kemudian': 'CC',
#  'dibawa': 'VB',
#  'las': 'NNP',
#  'vegas': 'NNP',
#  'dilihat': 'VB',
#  'calon': 'NN',
#  'pembeli': 'NN',
#  'namun': 'CC',
#  'disita': 'VB',
#  'polisi': 'NN',
#  'los': 'NNP',
#  'angeles': 'NNP',
#  'badut': 'NN',
#  'politikus': 'NN',
#  'ditantang': 'VB',
#  'baca': 'VB',
#  'tulis': 'VB',
#  'mempunyai': 'VB',
#  'peluang': 'NN',
#  'meraih': 'VB',
#  'kursi': 'NN',
#  'pemilihan': 'NN',
#  'minggu': 'NNP',
#  '(': 'Z',
#  '3': 'CD',
#  '/': 'Z',
#  ')': 'Z',
#  '-': 'Z',
#  'membuktikan': 'VB',
#  'membaca': 'VB',
#  'menulis': 'VB',
#  'jajak': 'NN',
#  'pendapat': 'NN',
#  'memperlihatkan': 'VB',
#  'tiririca': 'NNP',
#  'suara': 'NN',
#  'hakim': 'NN',
#  'sao': 'NNP',
#  'paulo': 'NNP',
#  'menuntut': 'VB',
#  'memenuhi': 'VB',
#  'persyaratan': 'NN',
#  'surat kabar': 'NN',
#  'sama': 'JJ',
#  'sepuluh': 'CD',
#  'buta aksara': 'JJ',
#  'bahasa sehari-hari': 'NN',
#  'portugis': 'NNP',
#  'tukang': 'NN',
#  'mengeluh': 'VB',
#  'sensasi': 'NN',
#  'kampanye': 'NN',
#  'video': 'NN',
#  'kocak': 'JJ',
#  'jutaan': 'CD',
#  'penonton': 'NN',
#  'youtube': 'NNP',
#  'antara': 'IN',
#  'menggunakan': 'VB',
#  'slogan': 'NN',
#  'buruk': 'JJ',
#  'lagi': 'RB',
#  'dilakukan': 'VB',
#  'wakil': 'NNP',
#  'anda': 'PRP',
#  '?': 'Z',
#  'sungguh': 'RB',
#  'tahu': 'VB',
#  'tapi': 'CC',
#  'pilih': 'VB',
#  'mencari tahu': 'VB',
#  'menggelar': 'VB',
#  'ujian': 'NN',
#  'aksara': 'NN',
#  'epoca': 'NNP',
#  'menayangkan': 'VB',
#  'tampak': 'VB',
#  'komisi': 'NNP',
#  'terlambat': 'VB',
#  'menghentikan': 'VB',
#  'pencalonan': 'NN',
#  'diberhentikan': 'VB',
#  'jika': 'SC',
#  'gagal': 'VB',
#  'kemampuan': 'NN',
#  'selebriti': 'NN',
#  'nama': 'NN',
#  'asli': 'JJ',
#  'francisco': 'NNP',
#  'everardo': 'NNP',
#  'oliveira': 'NNP',
#  'silva': 'NNP',
#  'bekerja': 'VB',
#  'sirkus': 'NN',
#  'delapan': 'CD',
#  'miskin': 'JJ',
#  'ceara': 'NNP',
#  'pengalaman': 'NN',
#  'salah seorang': 'CD',
#  'pelawak': 'NN',
#  'terkenal': 'VB',
#  'tv': 'NN',
#  'merupakan': 'VB',
#  'puluhan': 'CD',
#  'berasal': 'VB',
#  'olahraga': 'NN',
#  'maupun': 'CC',
#  'pertunjukan': 'NN',
#  'berjuang': 'VB',
#  'merebut': 'VB',
#  'majelis rendah': 'NN',
#  'bersaing': 'VB',
#  'melawan': 'VB',
#  'berpengalaman': 'VB',
#  'seluruhnya': 'RB',
#  'tercatat': 'VB',
#  '6.000': 'CD',
#  '27': 'CD',
#  'partai': 'NN',
#  '513': 'CD',
#  'diduga': 'VB',
#  'kemenangan': 'NN',
#  'mutlak': 'JJ',
#  'romario': 'NNP',
#  'bintang': 'NN',
#  'sepak bola': 'NN',
#  'piala': 'NNP',
#  '1994': 'CD',
#  'pengamat': 'NN',
#  'popularitas': 'NN',
#  'mencerminkan': 'VB',
#  'kebingungan': 'NN',
#  'politik': 'NN',
#  'utama': 'NNP',
#  'marak': 'JJ',
#  'skandal': 'NN',
#  'korupsi': 'NN',
#  'ibu': 'NN',
#  'bayi': 'NN',
#  'anggota': 'NN',
#  'eropa': 'NNP',
#  'asal': 'IN',
#  'italia': 'NNP',
#  'sidang': 'NN',
#  'strasbourg': 'NNP',
#  'menggendong': 'VB',
#  'anak': 'NN',
#  'licia': 'NNP',
#  'ronzulli': 'NNP',
#  'ia': 'PRP',
#  'menunjukkan': 'VB',
#  'beban': 'NN',
#  'ditanggung': 'VB',
#  'kaum': 'NN',
#  'perempuan': 'NN',
#  'menjalani': 'VB',
#  'karir': 'NN',
#  'sekaligus': 'RB',
#  'mengasuh': 'VB',
#  'sedang': 'MD',
#  'membahas': 'VB',
#  'usul': 'NN',
#  'memperbaiki': 'VB',
#  'kesempatan': 'NN',
#  'vittoria': 'NNP',
#  'tidur': 'VB',
#  'nyenyak': 'JJ',
#  'berlangsung': 'VB',
#  'mewakili': 'VB',
#  'kebebasan': 'NNP',
#  'rakyat': 'NN',
#  'pimpinan': 'NN',
#  'pm': 'NNP',
#  'silvio': 'NNP',
#  'berlusconi': 'NNP',
#  'mendapat': 'VB',
#  'sambutan': 'NN',
#  'meriah': 'JJ',
#  'berdiri': 'VB',
#  'menyampaikan': 'VB',
#  'pidato': 'NN',
#  'sesama': 'NN',
#  'melihat': 'VB',
#  'komitmen': 'NN',
#  'persoalan-persoalan': 'NN',
#  'lembaga-lembaga': 'NN',
#  'dimulai': 'VB',
#  'naskah': 'NN',
#  'harry': 'NNP',
#  'potter': 'NNP',
#  'dipamerkan': 'VB',
#  'tangan': 'NN',
#  'pengarang': 'NN',
#  'jk': 'NNP',
#  'rowling': 'NNP',
#  'festival': 'NN',
#  'buku': 'NN',
#  'skotlandia': 'NNP',
#  'selatan': 'NNP',
#  'halaman': 'NN',
#  'dibingkai': 'VB',
#  'ditandatangani': 'VB',
#  'berisi': 'VB',
#  'balada': 'NN',
#  'nick': 'NNP',
#  'si': 'DT',
#  'kepala': 'NN',
#  'nyaris': 'RB',
#  'putus': 'VB',
#  'wigtown': 'NNP',
#  '24': 'CD',
#  'hantu': 'NN',
#  'awal': 'NN',
#  'kamar': 'NN',
#  'rahasia': 'NN',
#  'dibuang': 'VB',
#  'termasuk': 'VB',
#  'diterbitkan': 'VB',
#  'disumbangkan': 'VB',
#  'yayasan': 'NNP',
#  'kamus': 'NNP',
#  'bahasa': 'NNP',
#  '2005': 'CD',
#  'mendukung': 'VB',
#  'pengumpulan': 'NN',
#  'dana': 'NN',
#  'dimiliki': 'VB',
#  'kolektor': 'NN',
#  'terkemuka': 'JJ',
#  'inggris': 'NNP',
#  'jurnal': 'NNP',
#  'asia': 'NNP',
#  'literary': 'NNP',
#  'review': 'NNP',
#  'ilyas': 'NNP',
#  'khan': 'NNP',
#  'senang': 'JJ',
#  'ikut': 'VB',
#  'memamerkan': 'VB',
#  'cara': 'NN',
#  'bagus': 'JJ',
#  'australia': 'NNP',
#  'salah': 'JJ',
#  'sebut': 'VB',
#  'pemenang': 'NN',
#  'next': 'NNP',
#  'top': 'JJ',
#  'model': 'NN',
#  'mengumumkan': 'VB',
#  'final': 'NN',
#  'disiarkan': 'VB',
#  'langsung': 'RB',
#  'seri': 'NN',
#  'keenam': 'OD',
#  'kelsey': 'NNP',
#  'martinovich': 'NNP',
#  'dianugerahi': 'VB',
#  'mahkota': 'NN',
#  'pilihan': 'NN',
#  'pemirsa': 'NN',
#  'presenter': 'NNP',
#  'sarah': 'NNP',
#  'murdoch': 'NNP',
#  'menyela': 'VB',
#  'sambil': 'SC',
#  'menggeleng-gelengkan': 'VB',
#  'ear': 'FW',
#  'piece': 'FW',
#  'mual': 'JJ',
#  'amat': 'RB',
#  'meminta': 'VB',
#  'maaf': 'NN',
#  'semata-mata': 'RB',
#  'kecelakaan': 'NN',
#  'yaitu': 'SC',
#  'amanda': 'NNP',
#  'ware': 'NNP',
#  '18': 'CD',
#  'terjadi': 'VB',
#  'siaran': 'NN',
#  'edan': 'JJ',
#  'adapun': 'CC',
#  'sekitar': 'RB',
#  'menit': 'NN',
#  'menerima': 'VB',
#  'kesalahan': 'NN',
#  'baik': 'JJ',
#  'ok': 'FW',
#  'kekeliruan': 'NN',
#  'berusaha': 'VB',
#  'menjelaskan': 'VB',
#  'selisih': 'NN',
#  'ketat': 'JJ',
#  'memimpin': 'VB',
#  'terus-menerus': 'RB',
#  'berganti': 'VB',
#  'benar-benar': 'RB',
#  'tergantung': 'VB',
#  'maju': 'JJ',
#  'mundur': 'VB',
#  'finalis': 'NN',
#  'berpelukan': 'VB',
#  'mengucapkan': 'VB',
#  'terima kasih': 'NN',
#  'pendukung': 'NN',
#  'berjalan': 'VB',
#  'catwalk': 'FW',
#  'kali': 'NND',
#  'merangkap': 'VB',
#  'menikah': 'VB',
#  'putra': 'NN',
#  'rupert': 'NNP',
#  'lachlan': 'NNP',
#  'don': 'NNP',
#  'quixote': 'NNP',
#  'akademi': 'NNP',
#  'kerajaan': 'NNP',
#  'spanyol': 'NNP',
#  'mengundang': 'VB',
#  'merekam': 'VB',
#  'segmen': 'NN',
#  'novel': 'NN',
#  'klasik': 'JJ',
#  'mengunggah': 'VB',
#  'karya': 'NN',
#  'miguel': 'NNP',
#  'de': 'NNP',
#  'cervantes': 'NNP',
#  'paling': 'RB',
#  'populer': 'JJ',
#  'walau': 'SC',
#  'pelindung': 'NN',
#  'membagi': 'VB',
#  '2.000': 'CD',
#  'segmen-segmen': 'NN',
#  'dibaca': 'VB',
#  'direkam': 'VB',
#  'sukarelawan': 'NN',
#  'diunggah': 'VB',
#  'tujuan': 'NN',
#  'mempromosikan': 'VB',
#  'lengkap': 'JJ',
#  'ingenious': 'NNP',
#  'hidalgo': 'NNP',
#  'of': 'NNP',
#  'la': 'NNP',
#  'mancha': 'NNP',
#  'ruang': 'NN',
#  'sepatutnya': 'RB',
#  'internet': 'NN',
#  'sekretaris': 'NNP',
#  'dario': 'NNP',
#  'villanueva': 'NNP',
#  'mengadukan': 'VB',
#  'melakukan': 'VB',
#  'sesuatu': 'PRP',
#  'mengoreksi': 'VB',
#  '1605': 'CD',
#  'berkisah': 'VB',
#  'petualangan': 'NN',
#  'pria': 'NN',
#  'pensiunan': 'NN',
#  'kawasan': 'NN',
#  'punya': 'VB',
#  'obsesi': 'NN',
#  'gagasan-gagasan': 'NN',
#  'kesatria': 'NN',
#  'terdiri': 'VB',
#  'bab': 'NN',
#  'hampir': 'RB',
#  '1.000': 'CD',
#  'berminat': 'VB',
#  'mendaftarkan': 'VB',
#  'terpilih': 'VB',
#  'tertentu': 'JJ',
#  'hobbit': 'NNP',
#  'cari': 'VB',
#  'aktor': 'NN',
#  'kerdil': 'JJ',
#  'tim': 'NN',
#  'pembuat': 'NN',
#  'mencari': 'VB',
#  'selandia': 'NNP',
#  'sementara': 'SC',
#  'sutradara': 'NN',
#  'peter': 'NNP',
#  'jackson': 'NNP',
#  'berancang-ancang': 'VB',
#  'merealisasikan': 'VB',
#  'rencana': 'NN',
#  'oscar': 'NNP',
#  'lord': 'NNP',
#  'rings': 'NNP',
#  'return': 'NNP',
#  'king': 'NNP',
#  'iklan': 'NN',
#  'koran': 'NN',
#  'terbitan': 'NN',
#  'wellington': 'NNP',
#  'wingnut': 'NNP',
#  'films': 'NNP',
#  'badan': 'NNP',
#  '123': 'CD',
#  'cm': 'NND',
#  'maksimum': 'NN',
#  '158': 'CD',
#  'proyek': 'NN',
#  'lampu hijau': 'NN',
#  'perusahaan': 'NN',
#  'perfilman': 'NN',
#  'mgm': 'NNP',
#  'studios': 'NNP',
#  'keuangan': 'NN',
#  'tengah': 'MD',
#  'dialami': 'VB',
#  'juru bicara': 'NN',
#  'bersiap-siap': 'VB',
#  'scale': 'FW',
#  'double': 'FW',
#  'mengisi': 'VB',
#  'peran': 'NN',
#  'dialog': 'NN',
#  'sedangkan': 'CC',
#  'audisi': 'NN',
#  'diadakan': 'VB',
#  'figuran': 'NN',
#  'wide': 'FW',
#  'shot': 'FW',
#  'pengganti': 'NN',
#  'dewasa': 'JJ',
#  'memerlukan': 'VB',
#  'terlihat': 'VB',
#  'atau': 'CC',
#  'menambahkan': 'VB',
#  'pelamar': 'NN',
#  '16': 'CD',
#  'siapa pun': 'SC',
#  'ketentuan': 'NN',
#  'ditolak': 'VB',
#  'berkaki': 'VB',
#  'pendek': 'JJ',
#  'meski': 'SC',
#  'syarat': 'NN',
#  'layak': 'JJ',
#  'dipilih': 'VB',
#  'jangkung': 'JJ',
#  'karakter': 'NN',
#  'fiksi': 'NN',
#  'ciptaan': 'NN',
#  'jrr': 'NNP',
#  'tolkien': 'NNP',
#  'prolog': 'NN',
#  'menggambarkan': 'VB',
#  'hobbits': 'NNP',
#  'berukuran': 'VB',
#  'tiga': 'CD',
#  'kaki': 'NND',
#  '60': 'CD',
#  '120': 'CD',
#  'rata-rata': 'NN',
#  'inci': 'NND',
#  '75': 'CD',
#  'surat-surat': 'NN',
#  'penampakan': 'NN',
#  'fisik': 'NN',
#  'sosok': 'NN',
#  'protagonis': 'NN',
#  'bilbo': 'NNP',
#  'baggins': 'NNP',
#  'agak': 'RB',
#  'tambun': 'JJ',
#  'perut': 'NN',
#  'bulat': 'JJ',
#  'jenaka': 'JJ',
#  ';': 'Z',
#  'telinga': 'NN',
#  'sedikit': 'RB',
#  'runcing': 'JJ',
#  'kurcaci': 'NN',
#  'rambut': 'NN',
#  'keriting': 'JJ',
#  'cokelat': 'JJ',
#  'mata kaki': 'NN',
#  'bawah': 'NN',
#  'tertutup': 'VB',
#  'bulu': 'NN',
#  'tambah': 'VB',
#  'pencarian': 'NN',
#  'casting': 'FW',
#  'dijadwalkan': 'VB',
#  'hari': 'NN',
#  'national': 'NNP',
#  'dance': 'NNP',
#  'and': 'NNP',
#  'drama': 'NNP',
#  'centre': 'NNP',
#  'kelahiran': 'NN',
#  'meksiko': 'NNP',
#  'guillermo': 'NNP',
#  'del': 'NNP',
#  'toro': 'NNP',
#  'bersedia': 'VB',
#  'menarik diri': 'VB',
#  'alasan': 'NN',
#  'produksi': 'NN',
#  'tertunda': 'VB',
#  'terbaik': 'JJ',
#  'menggantikan': 'VB',
#  'pengumuman': 'NN',
#  'pergantian': 'NN',
#  'pencurian': 'NN',
#  'ladang': 'NN',
#  'anggur': 'NN',
#  'pencuri': 'NN',
#  'prancis': 'NNP',
#  'masuk': 'VB',
#  'mencuri': 'VB',
#  'panenan': 'NN',
#  'cabernet': 'NNP',
#  'sauvignon': 'NNP',
#  'aksi': 'NN',
#  'villeneuve': 'NNP',
#  'les-beziers': 'NNP',
#  'malam': 'NN',
#  '9': 'CD',
#  'memanfaatkan': 'VB',
#  'terang bulan': 'JJ',
#  'ton': 'NND',
#  'mesin': 'NN',
#  'petani': 'NNP',
#  ...}

# %%
#Menghitung akurasi
def accuracy(test_sentences, test_tags, max_frekuensi_tag):
    accuracy = 0
    count_word = 0
    for i in range(len(test_sentences)):
        for j in range(len(test_sentences[i])):
            if test_sentences[i][j] in max_frekuensi_tag:
                if test_tags[i][j] == max_frekuensi_tag[test_sentences[i][j]]:
                     accuracy += 1  
            count_word += 1
    
    print("Akurasi : ",(accuracy/count_word)*100)
accuracy(test_sentences, test_tags, max_frekuensi_tag)
# Out:
# Akurasi :  83.23529411764706
