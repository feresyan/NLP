# %% [markdown]
# # Decision Tree

# %%
#load dataset
def read_dataset(fname):
    sentences = []
    tags = []
    with open(fname) as f:
        content = f.readlines()
    # you may also want to remove whitespace characters like `\n` at the end of each line
    content = [x.strip() for x in content]
    idx_line = 0
    while idx_line < len(content):
        sent = []
        tag = []
        print('idx_line =')
        print(idx_line)
        while not content[idx_line].startswith('</kalimat'):
            if  not content[idx_line].startswith('<kalimat'):
                content_part = content[idx_line].split('\t')
                sent.append(content_part[0])
                tag.append(content_part[1])
            idx_line = idx_line + 1
        sentences.append(sent)
        tags.append(tag)
        idx_line = idx_line+2        
    return sentences, tags

# %%
def features(sentence, index):
    """ sentence: [w1, w2, ...], index: the index of the word """
    return {
        'word': sentence[index],
        'prefix-1': sentence[index][0],
        'prefix-2': sentence[index][:2],
        'prefix-3': sentence[index][:3],
        'suffix-1': sentence[index][-1],
        'suffix-2': sentence[index][-2:],
        'suffix-3': sentence[index][-3:],
        'prev_word': '' if index == 0 else sentence[index - 1],
        'next_word': '' if index == len(sentence) - 1 else sentence[index + 1],
    }

# %%
def transform_to_dataset(sentences, tags):
    X, y = [], []
 
    for sentence_idx in range(len(sentences)):
        for index in range(len(sentences[sentence_idx])):
            X.append(features(sentences[sentence_idx], index))
            y.append(tags[sentence_idx][index])
 
    return X, y

# %%
sentences,tags = read_dataset('data_train.txt')
print(sentences[1])
print(tags[1])

# 1000 data awal untuk data train dan 20 data berikutnya untuk data test
# cutoff = int(.75 * len(sentences))
training_sentences = sentences[0:1000]
test_sentences = sentences[1001:1020]
training_tags = tags[0:1000]
test_tags = tags[1001:1020]
# Out:
# idx_line =
# 0
# idx_line =
# 7
# idx_line =
# 27
# idx_line =
# 46
# idx_line =
# 63
# idx_line =
# 86
# idx_line =
# 105
# idx_line =
# 127
# idx_line =
# 145
# idx_line =
# 159
# idx_line =
# 189
# idx_line =
# 198
# idx_line =
# 213
# idx_line =
# 227
# idx_line =
# 241
# idx_line =
# 257
# idx_line =
# 274
# idx_line =
# 289
# idx_line =
# 296
# idx_line =
# 319
# idx_line =
# 337
# idx_line =
# 354
# idx_line =
# 377
# idx_line =
# 392
# idx_line =
# 419
# idx_line =
# 439
# idx_line =
# 455
# idx_line =
# 476
# idx_line =
# 499
# idx_line =
# 516
# idx_line =
# 539
# idx_line =
# 546
# idx_line =
# 560
# idx_line =
# 585
# idx_line =
# 601
# idx_line =
# 622
# idx_line =
# 655
# idx_line =
# 689
# idx_line =
# 706
# idx_line =
# 738
# idx_line =
# 765
# idx_line =
# 776
# idx_line =
# 792
# idx_line =
# 828
# idx_line =
# 834
# idx_line =
# 856
# idx_line =
# 875
# idx_line =
# 899
# idx_line =
# 919
# idx_line =
# 960
# idx_line =
# 984
# idx_line =
# 1001
# idx_line =
# 1017
# idx_line =
# 1034
# idx_line =
# 1053
# idx_line =
# 1090
# idx_line =
# 1111
# idx_line =
# 1118
# idx_line =
# 1151
# idx_line =
# 1169
# idx_line =
# 1186
# idx_line =
# 1203
# idx_line =
# 1222
# idx_line =
# 1236
# idx_line =
# 1275
# idx_line =
# 1298
# idx_line =
# 1322
# idx_line =
# 1326
# idx_line =
# 1353
# idx_line =
# 1369
# idx_line =
# 1399
# idx_line =
# 1415
# idx_line =
# 1444
# idx_line =
# 1464
# idx_line =
# 1471
# idx_line =
# 1490
# idx_line =
# 1512
# idx_line =
# 1530
# idx_line =
# 1545
# idx_line =
# 1568
# idx_line =
# 1602
# idx_line =
# 1609
# idx_line =
# 1637
# idx_line =
# 1658
# idx_line =
# 1675
# idx_line =
# 1707
# idx_line =
# 1735
# idx_line =
# 1764
# idx_line =
# 1796
# idx_line =
# 1819
# idx_line =
# 1826
# idx_line =
# 1853
# idx_line =
# 1874
# idx_line =
# 1903
# idx_line =
# 1920
# idx_line =
# 1937
# idx_line =
# 1948
# idx_line =
# 1969
# idx_line =
# 1982
# idx_line =
# 1997
# idx_line =
# 2023
# idx_line =
# 2046
# idx_line =
# 2066
# idx_line =
# 2073
# idx_line =
# 2097
# idx_line =
# 2120
# idx_line =
# 2143
# idx_line =
# 2166
# idx_line =
# 2194
# idx_line =
# 2219
# idx_line =
# 2234
# idx_line =
# 2261
# idx_line =
# 2276
# idx_line =
# 2298
# idx_line =
# 2305
# idx_line =
# 2330
# idx_line =
# 2352
# idx_line =
# 2380
# idx_line =
# 2402
# idx_line =
# 2415
# idx_line =
# 2445
# idx_line =
# 2483
# idx_line =
# 2506
# idx_line =
# 2512
# idx_line =
# 2536
# idx_line =
# 2581
# idx_line =
# 2619
# idx_line =
# 2655
# idx_line =
# 2675
# idx_line =
# 2705
# idx_line =
# 2746
# idx_line =
# 2751
# idx_line =
# 2773
# idx_line =
# 2801
# idx_line =
# 2826
# idx_line =
# 2837
# idx_line =
# 2871
# idx_line =
# 2901
# idx_line =
# 2925
# idx_line =
# 2944
# idx_line =
# 2958
# idx_line =
# 2978
# idx_line =
# 2992
# idx_line =
# 2999
# idx_line =
# 3022
# idx_line =
# 3041
# idx_line =
# 3066
# idx_line =
# 3082
# idx_line =
# 3103
# idx_line =
# 3121
# idx_line =
# 3140
# idx_line =
# 3147
# idx_line =
# 3175
# idx_line =
# 3197
# idx_line =
# 3204
# idx_line =
# 3212
# idx_line =
# 3223
# idx_line =
# 3245
# idx_line =
# 3249
# idx_line =
# 3282
# idx_line =
# 3313
# idx_line =
# 3332
# idx_line =
# 3346
# idx_line =
# 3370
# idx_line =
# 3399
# idx_line =
# 3432
# idx_line =
# 3436
# idx_line =
# 3461
# idx_line =
# 3486
# idx_line =
# 3499
# idx_line =
# 3527
# idx_line =
# 3561
# idx_line =
# 3603
# idx_line =
# 3633
# idx_line =
# 3656
# idx_line =
# 3664
# idx_line =
# 3698
# idx_line =
# 3730
# idx_line =
# 3754
# idx_line =
# 3780
# idx_line =
# 3815
# idx_line =
# 3840
# idx_line =
# 3862
# idx_line =
# 3891
# idx_line =
# 3920
# idx_line =
# 3949
# idx_line =
# 3972
# idx_line =
# 3995
# idx_line =
# 4006
# idx_line =
# 4014
# idx_line =
# 4032
# idx_line =
# 4055
# idx_line =
# 4075
# idx_line =
# 4094
# idx_line =
# 4101
# idx_line =
# 4120
# idx_line =
# 4137
# idx_line =
# 4164
# idx_line =
# 4199
# idx_line =
# 4250
# idx_line =
# 4284
# idx_line =
# 4317
# idx_line =
# 4334
# idx_line =
# 4359
# idx_line =
# 4390
# idx_line =
# 4410
# idx_line =
# 4443
# idx_line =
# 4480
# idx_line =
# 4515
# idx_line =
# 4531
# idx_line =
# 4554
# idx_line =
# 4570
# idx_line =
# 4592
# idx_line =
# 4620
# idx_line =
# 4641
# idx_line =
# 4656
# idx_line =
# 4696
# idx_line =
# 4725
# idx_line =
# 4742
# idx_line =
# 4757
# idx_line =
# 4777
# idx_line =
# 4801
# idx_line =
# 4814
# idx_line =
# 4832
# idx_line =
# 4851
# idx_line =
# 4897
# idx_line =
# 4947
# idx_line =
# 4990
# idx_line =
# 5016
# idx_line =
# 5047
# idx_line =
# 5081
# idx_line =
# 5121
# idx_line =
# 5157
# idx_line =
# 5193
# idx_line =
# 5240
# idx_line =
# 5273
# idx_line =
# 5310
# idx_line =
# 5325
# idx_line =
# 5369
# idx_line =
# 5390
# idx_line =
# 5412
# idx_line =
# 5434
# idx_line =
# 5467
# idx_line =
# 5498
# idx_line =
# 5516
# idx_line =
# 5537
# idx_line =
# 5556
# idx_line =
# 5582
# idx_line =
# 5626
# idx_line =
# 5647
# idx_line =
# 5678
# idx_line =
# 5700
# idx_line =
# 5721
# idx_line =
# 5751
# idx_line =
# 5792
# idx_line =
# 5825
# idx_line =
# 5843
# idx_line =
# 5872
# idx_line =
# 5912
# idx_line =
# 5978
# idx_line =
# 6000
# idx_line =
# 6021
# idx_line =
# 6057
# idx_line =
# 6092
# idx_line =
# 6106
# idx_line =
# 6142
# idx_line =
# 6184
# idx_line =
# 6209
# idx_line =
# 6243
# idx_line =
# 6263
# idx_line =
# 6312
# idx_line =
# 6347
# idx_line =
# 6390
# idx_line =
# 6445
# idx_line =
# 6495
# idx_line =
# 6519
# idx_line =
# 6567
# idx_line =
# 6586
# idx_line =
# 6605
# idx_line =
# 6639
# idx_line =
# 6685
# idx_line =
# 6717
# idx_line =
# 6749
# idx_line =
# 6799
# idx_line =
# 6834
# idx_line =
# 6873
# idx_line =
# 6894
# idx_line =
# 6924
# idx_line =
# 6966
# idx_line =
# 6996
# idx_line =
# 7027
# idx_line =
# 7063
# idx_line =
# 7088
# idx_line =
# 7134
# idx_line =
# 7165
# idx_line =
# 7183
# idx_line =
# 7217
# idx_line =
# 7246
# idx_line =
# 7268
# idx_line =
# 7277
# idx_line =
# 7319
# idx_line =
# 7346
# idx_line =
# 7391
# idx_line =
# 7430
# idx_line =
# 7470
# idx_line =
# 7502
# idx_line =
# 7517
# idx_line =
# 7536
# idx_line =
# 7550
# idx_line =
# 7571
# idx_line =
# 7607
# idx_line =
# 7637
# idx_line =
# 7656
# idx_line =
# 7690
# idx_line =
# 7716
# idx_line =
# 7752
# idx_line =
# 7783
# idx_line =
# 7811
# idx_line =
# 7850
# idx_line =
# 7858
# idx_line =
# 7892
# idx_line =
# 7916
# idx_line =
# 7925
# idx_line =
# 7939
# idx_line =
# 7958
# idx_line =
# 7992
# idx_line =
# 8036
# idx_line =
# 8074
# idx_line =
# 8110
# idx_line =
# 8133
# idx_line =
# 8154
# idx_line =
# 8177
# idx_line =
# 8200
# idx_line =
# 8232
# idx_line =
# 8279
# idx_line =
# 8331
# idx_line =
# 8394
# idx_line =
# 8439
# idx_line =
# 8479
# idx_line =
# 8505
# idx_line =
# 8545
# idx_line =
# 8589
# idx_line =
# 8624
# idx_line =
# 8664
# idx_line =
# 8694
# idx_line =
# 8732
# idx_line =
# 8779
# idx_line =
# 8824
# idx_line =
# 8858
# idx_line =
# 8896
# idx_line =
# 8929
# idx_line =
# 8949
# idx_line =
# 8993
# idx_line =
# 9026
# idx_line =
# 9060
# idx_line =
# 9084
# idx_line =
# 9112
# idx_line =
# 9137
# idx_line =
# 9151
# idx_line =
# 9193
# idx_line =
# 9242
# idx_line =
# 9269
# idx_line =
# 9291
# idx_line =
# 9323
# idx_line =
# 9361
# idx_line =
# 9381
# idx_line =
# 9409
# idx_line =
# 9443
# idx_line =
# 9480
# idx_line =
# 9499
# idx_line =
# 9523
# idx_line =
# 9553
# idx_line =
# 9582
# idx_line =
# 9616
# idx_line =
# 9641
# idx_line =
# 9669
# idx_line =
# 9696
# idx_line =
# 9738
# idx_line =
# 9777
# idx_line =
# 9809
# idx_line =
# 9831
# idx_line =
# 9862
# idx_line =
# 9891
# idx_line =
# 9909
# idx_line =
# 9943
# idx_line =
# 9970
# idx_line =
# 9994
# idx_line =
# 10024
# idx_line =
# 10050
# idx_line =
# 10091
# idx_line =
# 10105
# idx_line =
# 10129
# idx_line =
# 10148
# idx_line =
# 10172
# idx_line =
# 10192
# idx_line =
# 10213
# idx_line =
# 10249
# idx_line =
# 10297
# idx_line =
# 10318
# idx_line =
# 10380
# idx_line =
# 10408
# idx_line =
# 10448
# idx_line =
# 10471
# idx_line =
# 10483
# idx_line =
# 10507
# idx_line =
# 10525
# idx_line =
# 10550
# idx_line =
# 10589
# idx_line =
# 10629
# idx_line =
# 10665
# idx_line =
# 10698
# idx_line =
# 10752
# idx_line =
# 10776
# idx_line =
# 10807
# idx_line =
# 10831
# idx_line =
# 10858
# idx_line =
# 10876
# idx_line =
# 10909
# idx_line =
# 10950
# idx_line =
# 10986
# idx_line =
# 11026
# idx_line =
# 11056
# idx_line =
# 11094
# idx_line =
# 11117
# idx_line =
# 11129
# idx_line =
# 11157
# idx_line =
# 11188
# idx_line =
# 11209
# idx_line =
# 11244
# idx_line =
# 11295
# idx_line =
# 11318
# idx_line =
# 11350
# idx_line =
# 11379
# idx_line =
# 11414
# idx_line =
# 11445
# idx_line =
# 11491
# idx_line =
# 11509
# idx_line =
# 11532
# idx_line =
# 11562
# idx_line =
# 11580
# idx_line =
# 11606
# idx_line =
# 11647
# idx_line =
# 11675
# idx_line =
# 11705
# idx_line =
# 11736
# idx_line =
# 11759
# idx_line =
# 11768
# idx_line =
# 11790
# idx_line =
# 11812
# idx_line =
# 11841
# idx_line =
# 11865
# idx_line =
# 11895
# idx_line =
# 11920
# idx_line =
# 11967
# idx_line =
# 11998
# idx_line =
# 12052
# idx_line =
# 12086
# idx_line =
# 12118
# idx_line =
# 12131
# idx_line =
# 12162
# idx_line =
# 12183
# idx_line =
# 12238
# idx_line =
# 12270
# idx_line =
# 12310
# idx_line =
# 12352
# idx_line =
# 12379
# idx_line =
# 12421
# idx_line =
# 12467
# idx_line =
# 12513
# idx_line =
# 12535
# idx_line =
# 12577
# idx_line =
# 12600
# idx_line =
# 12633
# idx_line =
# 12670
# idx_line =
# 12700
# idx_line =
# 12726
# idx_line =
# 12758
# idx_line =
# 12795
# idx_line =
# 12816
# idx_line =
# 12845
# idx_line =
# 12864
# idx_line =
# 12905
# idx_line =
# 12945
# idx_line =
# 12999
# idx_line =
# 13049
# idx_line =
# 13093
# idx_line =
# 13146
# idx_line =
# 13180
# idx_line =
# 13209
# idx_line =
# 13268
# idx_line =
# 13299
# idx_line =
# 13312
# idx_line =
# 13321
# idx_line =
# 13349
# idx_line =
# 13364
# idx_line =
# 13378
# idx_line =
# 13401
# idx_line =
# 13420
# idx_line =
# 13438
# idx_line =
# 13458
# idx_line =
# 13473
# idx_line =
# 13497
# idx_line =
# 13516
# idx_line =
# 13533
# idx_line =
# 13562
# idx_line =
# 13598
# idx_line =
# 13628
# idx_line =
# 13668
# idx_line =
# 13684
# idx_line =
# 13735
# idx_line =
# 13757
# idx_line =
# 13775
# idx_line =
# 13817
# idx_line =
# 13868
# idx_line =
# 13896
# idx_line =
# 13933
# idx_line =
# 13974
# idx_line =
# 14015
# idx_line =
# 14030
# idx_line =
# 14062
# idx_line =
# 14083
# idx_line =
# 14127
# idx_line =
# 14156
# idx_line =
# 14185
# idx_line =
# 14200
# idx_line =
# 14221
# idx_line =
# 14245
# idx_line =
# 14278
# idx_line =
# 14322
# idx_line =
# 14357
# idx_line =
# 14396
# idx_line =
# 14411
# idx_line =
# 14436
# idx_line =
# 14457
# idx_line =
# 14483
# idx_line =
# 14499
# idx_line =
# 14531
# idx_line =
# 14561
# idx_line =
# 14579
# idx_line =
# 14602
# idx_line =
# 14635
# idx_line =
# 14659
# idx_line =
# 14680
# idx_line =
# 14711
# idx_line =
# 14721
# idx_line =
# 14731
# idx_line =
# 14759
# idx_line =
# 14792
# idx_line =
# 14803
# idx_line =
# 14826
# idx_line =
# 14862
# idx_line =
# 14899
# idx_line =
# 14920
# idx_line =
# 14942
# idx_line =
# 14977
# idx_line =
# 14995
# idx_line =
# 15014
# idx_line =
# 15042
# idx_line =
# 15098
# idx_line =
# 15130
# idx_line =
# 15177
# idx_line =
# 15225
# idx_line =
# 15255
# idx_line =
# 15289
# idx_line =
# 15328
# idx_line =
# 15353
# idx_line =
# 15386
# idx_line =
# 15431
# idx_line =
# 15464
# idx_line =
# 15492
# idx_line =
# 15516
# idx_line =
# 15545
# idx_line =
# 15579
# idx_line =
# 15602
# idx_line =
# 15655
# idx_line =
# 15679
# idx_line =
# 15700
# idx_line =
# 15719
# idx_line =
# 15748
# idx_line =
# 15772
# idx_line =
# 15800
# idx_line =
# 15831
# idx_line =
# 15847
# idx_line =
# 15866
# idx_line =
# 15904
# idx_line =
# 15917
# idx_line =
# 15962
# idx_line =
# 15995
# idx_line =
# 16013
# idx_line =
# 16036
# idx_line =
# 16052
# idx_line =
# 16078
# idx_line =
# 16097
# idx_line =
# 16123
# idx_line =
# 16151
# idx_line =
# 16170
# idx_line =
# 16223
# idx_line =
# 16252
# idx_line =
# 16297
# idx_line =
# 16339
# idx_line =
# 16363
# idx_line =
# 16390
# idx_line =
# 16434
# idx_line =
# 16471
# idx_line =
# 16491
# idx_line =
# 16512
# idx_line =
# 16564
# idx_line =
# 16608
# idx_line =
# 16639
# idx_line =
# 16670
# idx_line =
# 16701
# idx_line =
# 16727
# idx_line =
# 16748
# idx_line =
# 16772
# idx_line =
# 16798
# idx_line =
# 16840
# idx_line =
# 16860
# idx_line =
# 16879
# idx_line =
# 16908
# idx_line =
# 16935
# idx_line =
# 16948
# idx_line =
# 16970
# idx_line =
# 17010
# idx_line =
# 17046
# idx_line =
# 17073
# idx_line =
# 17098
# idx_line =
# 17125
# idx_line =
# 17168
# idx_line =
# 17191
# idx_line =
# 17215
# idx_line =
# 17265
# idx_line =
# 17287
# idx_line =
# 17306
# idx_line =
# 17332
# idx_line =
# 17376
# idx_line =
# 17417
# idx_line =
# 17440
# idx_line =
# 17462
# idx_line =
# 17490
# idx_line =
# 17528
# idx_line =
# 17558
# idx_line =
# 17574
# idx_line =
# 17587
# idx_line =
# 17625
# idx_line =
# 17663
# idx_line =
# 17699
# idx_line =
# 17707
# idx_line =
# 17733
# idx_line =
# 17749
# idx_line =
# 17763
# idx_line =
# 17785
# idx_line =
# 17802
# idx_line =
# 17822
# idx_line =
# 17836
# idx_line =
# 17866
# idx_line =
# 17886
# idx_line =
# 17909
# idx_line =
# 17929
# idx_line =
# 17952
# idx_line =
# 17977
# idx_line =
# 18021
# idx_line =
# 18052
# idx_line =
# 18073
# idx_line =
# 18109
# idx_line =
# 18139
# idx_line =
# 18161
# idx_line =
# 18206
# idx_line =
# 18262
# idx_line =
# 18304
# idx_line =
# 18334
# idx_line =
# 18379
# idx_line =
# 18408
# idx_line =
# 18437
# idx_line =
# 18466
# idx_line =
# 18505
# idx_line =
# 18525
# idx_line =
# 18548
# idx_line =
# 18561
# idx_line =
# 18644
# idx_line =
# 18687
# idx_line =
# 18725
# idx_line =
# 18763
# idx_line =
# 18802
# idx_line =
# 18819
# idx_line =
# 18838
# idx_line =
# 18854
# idx_line =
# 18876
# idx_line =
# 18904
# idx_line =
# 18929
# idx_line =
# 18952
# idx_line =
# 18977
# idx_line =
# 18993
# idx_line =
# 19031
# idx_line =
# 19055
# idx_line =
# 19116
# idx_line =
# 19142
# idx_line =
# 19179
# idx_line =
# 19207
# idx_line =
# 19237
# idx_line =
# 19263
# idx_line =
# 19288
# idx_line =
# 19333
# idx_line =
# 19382
# idx_line =
# 19411
# idx_line =
# 19432
# idx_line =
# 19475
# idx_line =
# 19496
# idx_line =
# 19515
# idx_line =
# 19543
# idx_line =
# 19566
# idx_line =
# 19590
# idx_line =
# 19607
# idx_line =
# 19624
# idx_line =
# 19637
# idx_line =
# 19651
# idx_line =
# 19679
# idx_line =
# 19699
# idx_line =
# 19715
# idx_line =
# 19731
# idx_line =
# 19746
# idx_line =
# 19777
# idx_line =
# 19806
# idx_line =
# 19842
# idx_line =
# 19866
# idx_line =
# 19890
# idx_line =
# 19909
# idx_line =
# 19926
# idx_line =
# 19941
# idx_line =
# 19965
# idx_line =
# 19991
# idx_line =
# 20037
# idx_line =
# 20083
# idx_line =
# 20107
# idx_line =
# 20127
# idx_line =
# 20152
# idx_line =
# 20180
# idx_line =
# 20216
# idx_line =
# 20262
# idx_line =
# 20316
# idx_line =
# 20346
# idx_line =
# 20385
# idx_line =
# 20423
# idx_line =
# 20461
# idx_line =
# 20488
# idx_line =
# 20500
# idx_line =
# 20522
# idx_line =
# 20532
# idx_line =
# 20570
# idx_line =
# 20590
# idx_line =
# 20626
# idx_line =
# 20667
# idx_line =
# 20684
# idx_line =
# 20708
# idx_line =
# 20728
# idx_line =
# 20772
# idx_line =
# 20795
# idx_line =
# 20812
# idx_line =
# 20838
# idx_line =
# 20869
# idx_line =
# 20885
# idx_line =
# 20909
# idx_line =
# 20923
# idx_line =
# 20933
# idx_line =
# 20960
# idx_line =
# 20986
# idx_line =
# 20998
# idx_line =
# 21023
# idx_line =
# 21075
# idx_line =
# 21110
# idx_line =
# 21143
# idx_line =
# 21163
# idx_line =
# 21185
# idx_line =
# 21232
# idx_line =
# 21262
# idx_line =
# 21291
# idx_line =
# 21319
# idx_line =
# 21337
# idx_line =
# 21361
# idx_line =
# 21402
# idx_line =
# 21426
# idx_line =
# 21441
# idx_line =
# 21462
# idx_line =
# 21498
# idx_line =
# 21530
# idx_line =
# 21552
# idx_line =
# 21569
# idx_line =
# 21600
# idx_line =
# 21629
# idx_line =
# 21666
# idx_line =
# 21705
# idx_line =
# 21732
# idx_line =
# 21773
# idx_line =
# 21800
# idx_line =
# 21843
# idx_line =
# 21874
# idx_line =
# 21893
# idx_line =
# 21910
# idx_line =
# 21932
# idx_line =
# 21967
# idx_line =
# 22004
# idx_line =
# 22032
# idx_line =
# 22053
# idx_line =
# 22076
# idx_line =
# 22097
# idx_line =
# 22116
# idx_line =
# 22161
# idx_line =
# 22172
# idx_line =
# 22191
# idx_line =
# 22218
# idx_line =
# 22246
# idx_line =
# 22268
# idx_line =
# 22299
# idx_line =
# 22336
# idx_line =
# 22362
# idx_line =
# 22399
# idx_line =
# 22430
# idx_line =
# 22443
# idx_line =
# 22461
# idx_line =
# 22485
# idx_line =
# 22494
# idx_line =
# 22524
# idx_line =
# 22553
# idx_line =
# 22579
# idx_line =
# 22607
# idx_line =
# 22640
# idx_line =
# 22672
# idx_line =
# 22704
# idx_line =
# 22730
# idx_line =
# 22750
# idx_line =
# 22773
# idx_line =
# 22801
# idx_line =
# 22843
# idx_line =
# 22888
# idx_line =
# 22919
# idx_line =
# 22942
# idx_line =
# 22980
# idx_line =
# 23031
# idx_line =
# 23085
# idx_line =
# 23128
# idx_line =
# 23163
# idx_line =
# 23208
# idx_line =
# 23239
# idx_line =
# 23295
# idx_line =
# 23345
# idx_line =
# 23383
# idx_line =
# 23423
# idx_line =
# 23450
# idx_line =
# 23487
# idx_line =
# 23511
# idx_line =
# 23538
# idx_line =
# 23587
# idx_line =
# 23624
# idx_line =
# 23662
# idx_line =
# 23692
# idx_line =
# 23737
# idx_line =
# 23778
# idx_line =
# 23798
# idx_line =
# 23816
# idx_line =
# 23859
# idx_line =
# 23874
# idx_line =
# 23900
# idx_line =
# 23939
# idx_line =
# 23974
# idx_line =
# 23988
# idx_line =
# 24027
# idx_line =
# 24059
# idx_line =
# 24093
# idx_line =
# 24127
# idx_line =
# 24151
# idx_line =
# 24175
# idx_line =
# 24192
# idx_line =
# 24221
# idx_line =
# 24235
# idx_line =
# 24268
# idx_line =
# 24284
# idx_line =
# 24301
# idx_line =
# 24354
# idx_line =
# 24399
# idx_line =
# 24436
# idx_line =
# 24464
# idx_line =
# 24484
# idx_line =
# 24527
# idx_line =
# 24564
# idx_line =
# 24592
# idx_line =
# 24610
# idx_line =
# 24646
# idx_line =
# 24690
# idx_line =
# 24713
# idx_line =
# 24754
# idx_line =
# 24792
# idx_line =
# 24810
# idx_line =
# 24843
# idx_line =
# 24894
# idx_line =
# 24922
# idx_line =
# 24971
# idx_line =
# 25006
# idx_line =
# 25054
# idx_line =
# 25082
# idx_line =
# 25102
# idx_line =
# 25143
# idx_line =
# 25189
# idx_line =
# 25213
# idx_line =
# 25231
# idx_line =
# 25257
# idx_line =
# 25276
# idx_line =
# 25295
# idx_line =
# 25320
# idx_line =
# 25348
# idx_line =
# 25376
# idx_line =
# 25416
# idx_line =
# 25454
# idx_line =
# 25501
# idx_line =
# 25526
# idx_line =
# 25559
# idx_line =
# 25597
# idx_line =
# 25624
# idx_line =
# 25657
# idx_line =
# 25682
# idx_line =
# 25708
# idx_line =
# 25732
# idx_line =
# 25753
# idx_line =
# 25765
# idx_line =
# 25783
# idx_line =
# 25821
# idx_line =
# 25848
# idx_line =
# 25871
# idx_line =
# 25898
# idx_line =
# 25921
# idx_line =
# 25950
# idx_line =
# 25985
# idx_line =
# 26028
# idx_line =
# 26052
# idx_line =
# 26061
# idx_line =
# 26105
# idx_line =
# 26125
# idx_line =
# 26141
# idx_line =
# 26169
# idx_line =
# 26192
# idx_line =
# 26214
# idx_line =
# 26244
# idx_line =
# 26274
# idx_line =
# 26302
# idx_line =
# 26343
# idx_line =
# 26371
# idx_line =
# 26404
# idx_line =
# 26420
# idx_line =
# 26448
# idx_line =
# 26480
# idx_line =
# 26510
# idx_line =
# 26552
# idx_line =
# 26596
# idx_line =
# 26643
# idx_line =
# 26665
# idx_line =
# 26689
# idx_line =
# 26723
# idx_line =
# 26754
# idx_line =
# 26800
# idx_line =
# 26842
# idx_line =
# 26875
# idx_line =
# 26899
# idx_line =
# 26920
# idx_line =
# 26951
# idx_line =
# 26997
# idx_line =
# 27016
# idx_line =
# 27070
# idx_line =
# 27100
# idx_line =
# 27134
# idx_line =
# 27157
# idx_line =
# 27206
# idx_line =
# 27253
# idx_line =
# 27290
# idx_line =
# 27315
# idx_line =
# 27330
# idx_line =
# 27367
# idx_line =
# 27394
# idx_line =
# 27422
# idx_line =
# 27450
# idx_line =
# 27474
# idx_line =
# 27502
# idx_line =
# 27523
# idx_line =
# 27553
# idx_line =
# 27577
# idx_line =
# 27608
# idx_line =
# 27638
# idx_line =
# 27659
# idx_line =
# 27685
# idx_line =
# 27712
# idx_line =
# 27746
# idx_line =
# 27774
# idx_line =
# 27794
# idx_line =
# 27818
# idx_line =
# 27838
# idx_line =
# 27875
# idx_line =
# 27916
# idx_line =
# 27932
# idx_line =
# 27947
# idx_line =
# 27973
# idx_line =
# 28020
# idx_line =
# 28051
# idx_line =
# 28093
# idx_line =
# 28122
# idx_line =
# 28168
# idx_line =
# 28203
# idx_line =
# 28229
# idx_line =
# 28265
# idx_line =
# 28303
# idx_line =
# 28330
# idx_line =
# 28352
# idx_line =
# 28389
# idx_line =
# 28414
# idx_line =
# 28451
# idx_line =
# 28470
# idx_line =
# 28502
# idx_line =
# 28540
# idx_line =
# 28588
# idx_line =
# 28635
# idx_line =
# 28680
# idx_line =
# 28702
# idx_line =
# 28732
# idx_line =
# 28789
# idx_line =
# 28842
# idx_line =
# 28889
# idx_line =
# 28901
# idx_line =
# 28921
# idx_line =
# 28959
# idx_line =
# 28986
# idx_line =
# 29002
# idx_line =
# 29046
# idx_line =
# 29084
# idx_line =
# 29138
# idx_line =
# 29178
# idx_line =
# 29217
# idx_line =
# 29241
# idx_line =
# 29260
# idx_line =
# 29300
# idx_line =
# 29338
# idx_line =
# 29371
# idx_line =
# 29416
# idx_line =
# 29441
# idx_line =
# 29476
# idx_line =
# 29506
# idx_line =
# 29543
# idx_line =
# 29561
# idx_line =
# 29583
# idx_line =
# 29601
# idx_line =
# 29625
# idx_line =
# 29640
# idx_line =
# 29665
# idx_line =
# 29681
# idx_line =
# 29699
# ['Pemerintah', 'kota', 'Delhi', 'mengerahkan', 'monyet', 'untuk', 'mengusir', 'monyet-monyet', 'lain', 'yang', 'berbadan', 'lebih', 'kecil', 'dari', 'arena', 'Pesta Olahraga', 'Persemakmuran', '.']
# ['NNP', 'NNP', 'NNP', 'VB', 'NN', 'SC', 'VB', 'NN', 'JJ', 'SC', 'VB', 'RB', 'JJ', 'IN', 'NN', 'NNP', 'NNP', 'Z']

# %%
print(len(training_sentences))   
print(len(test_sentences))
# Out:
# 1000
# 19

# %%
X, y = transform_to_dataset(training_sentences, training_tags)
print('data training ke-4 =')
print(X[3])
print('label training ke-4 =')
print(y[3])
# Out:
# data training ke-4 =
# {'word': 'pesta olahraga', 'prefix-1': 'p', 'prefix-2': 'pe', 'prefix-3': 'pes', 'suffix-1': 'a', 'suffix-2': 'ga', 'suffix-3': 'aga', 'prev_word': 'amankan', 'next_word': ''}
# label training ke-4 =
# NN

# %%
from sklearn import tree
from sklearn.feature_extraction import DictVectorizer
from sklearn.pipeline import Pipeline
 
clf = Pipeline([
    ('vectorizer', DictVectorizer(sparse=False)),
    ('classifier', tree.DecisionTreeClassifier(criterion='entropy'))
])
clf.fit(X, y)   
 
print('Training completed')
# Out:
# Training completed

# %%
X_test, y_test = transform_to_dataset(test_sentences, test_tags)

# %%
print("Accuracy:")
print(clf.score(X_test, y_test))
# Out:
# Accuracy:
# 0.9245283018867925

# %%
# Test model yang sudah dilatih dengan kalimat masukan bebas
from nltk import word_tokenize

def pos_tag(sentence):
    tags = clf.predict([features(sentence, index) for index in range(len(sentence))])
    #return zip(sentence, tags)
    return tags
 
print(pos_tag(word_tokenize('perusahaan sekarang sedang dalam proses finalisasi dokumentasi')))
# Out:
# ['NN' 'NN' 'MD' 'IN' 'NN' 'NN' 'NN']
